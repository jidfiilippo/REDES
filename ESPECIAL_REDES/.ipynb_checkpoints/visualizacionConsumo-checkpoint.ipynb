# %%
#en principio lo que uno esperaria es que si pintamos los nodos que toman alcohol en gran medida para los 3 años veriamos que crece 
import networkx as nx
import numpy as np
import matplotlib.pylab as plt       
# %matplotlib inline
from matplotlib.pyplot import title,xlabel,ylabel,show

# %%
#abrimos las matrices de adyacencia por amistad.
Friendship1  = np.loadtxt('friendship1.txt') 
Friendship2  = np.loadtxt('friendship2.txt') 
Friendship3  = np.loadtxt('friendship3(copia).txt')

F1=np.matrix(Friendship1)
F2=np.matrix(Friendship2)
F3=np.matrix(Friendship3)

imalos=[]
for i in range(160):
    if 1.0*(F1[i,:]==10).sum()==160:
        imalos.append(i)
    if 1.0*(F2[i,:]==10).sum()==160:
        imalos.append(i)
    if 1.0*(F3[i,:]==10).sum()==160:
        imalos.append(i)
        
malos=list(set(imalos))
malos=np.sort(malos)

F1=np.delete(F1, malos, axis=0)
F1=np.delete(F1,malos,axis=1)
F2=np.delete(F2, malos, axis=0)
F2=np.delete(F2,malos,axis=1)
F3=np.delete(F3, malos, axis=0)
F3=np.delete(F3,malos,axis=1)

g1=nx.from_numpy_matrix(F1,create_using=nx.DiGraph())
g2=nx.from_numpy_matrix(F2,create_using=nx.DiGraph())
g3=nx.from_numpy_matrix(F3,create_using=nx.DiGraph())

# %%
#aca vemos el consumo 
alcohol = np.loadtxt('alcohol(copia).txt',dtype=int, usecols=(0,1,2))
alcohol = np.matrix(alcohol)
alcohol = np.delete(alcohol, imalos,0)

alcohol1 = []
nodos = list(g1.nodes())

for k in range(len(nodos)):
    alcohol1.append(alcohol[k,0])
    
alcohol2 = []

for k in range(len(nodos)):
    alcohol2.append(alcohol[k,1])
    
    
alcohol3 = []

for k in range(len(nodos)):
    alcohol3.append(alcohol[k,2])

# %%
max(alcohol[:,0])
# Out:
# matrix([[5]])

# %%
#hago un diccionario 

dictAlcohol1 = dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dictAlcohol1.update({nodos[i] : alcohol1[i]})
    
#ahi tengo el nodo como key y el grado de consumo como value

#type(nodos)

# %%
dictAlcohol2 = dict()
for i in range(len(nodos)):
    dictAlcohol2.update({nodos[i] : alcohol2[i]})
    
dictAlcohol3 = dict()
for i in range(len(nodos)):
    dictAlcohol3.update({nodos[i] : alcohol3[i]})

# %%
def AssignConsumption(G,dict_level_consumption):
    for n in G.nodes:
        G.nodes[n]["consumption"] = dict_level_consumption[n]
    return

# %%
#list(nx.get_node_attributes(g1,'consumption').items())[0:9]  #chequeamos algunos casos

# %%
def color(g):
    if g==0:
        col='brown'
    if g==1:
        col='black'
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        col='hotpink'
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        col='deeppink'
    elif g==4:                   # definimos una funcion para asignar un color distinto a cada genero
        col='crimson'
    elif g==5:                   # definimos una funcion para asignar un color distinto a cada genero
        col='red'
    return col

# %%
def size(g):
    base = 150
    if g==0:
        size=base*1
    if g==1:
        size=base*2
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        size=base*4
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base*8
    elif g==4:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base * 14
    elif g==5:                   # definimos una funcion para asignar un color distinto a cada genero
        size=base * 22
    return size

# %%
import matplotlib.lines as mlines
import matplotlib.pyplot as plt

no = mlines.Line2D([], [], color='brown', marker='o', linestyle='None',
                          markersize=15, label='No contesta')
poco = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
                          markersize=15, label='No consume')
medio = mlines.Line2D([], [], color='hotpink', marker='o', linestyle='None',
                          markersize=15, label='1/2 veces por año')

mediomedio = mlines.Line2D([], [], color='deeppink', marker='o', linestyle='None',
                          markersize=15, label='1 por mes')
alto = mlines.Line2D([], [], color='crimson', marker='o', linestyle='None',
                          markersize=15, label='1 por semana')
altoalto = mlines.Line2D([], [], color='red', marker='o', linestyle='None',
                          markersize=15, label='+ 1 por semana')

# %%
#fijo la posicion de los nodos

pos = nx.spring_layout(g1)

# %%
#options = {'node_color':[color(g) for g in nx.get_node_attributes(g1,'consumption').values()],
#           'node_size':300,'with_labels':False}

#asigno atributo
AssignConsumption(g1,dictAlcohol1)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g1,'consumption').values()])

plt.legend(handles=[no,poco,medio,mediomedio,alto,altoalto],prop={'size': 20},loc=3)

plt.show()

# %%
#options = {'node_color':[color(g) for g in nx.get_node_attributes(g1,'consumption').values()],
#           'node_size':300,'with_labels':False}

#asigno atributo
AssignConsumption(g2,dictAlcohol2)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g2, 
        pos = pos, 
        node_list = g2.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g2,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g2,'consumption').values()])

#plt.legend(handles=[no,poco,medio,mediomedio,alto,altoalto],prop={'size': 20})

plt.show()

# %%
#options = {'node_color':[color(g) for g in nx.get_node_attributes(g1,'consumption').values()],
#           'node_size':300,'with_labels':False}

#asigno atributo
AssignConsumption(g3,dictAlcohol3)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g3, 
        pos = pos, 
        node_list = g3.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g3,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g3,'consumption').values()])

#plt.legend(handles=[no,poco,medio,mediomedio,alto,altoalto],prop={'size': 20})

#plt.show()

# %%
cannabis= np.loadtxt('cannabis(copia).txt',dtype=int, usecols=(0,1,2))
cannabis=np.matrix(cannabis)
cannabis=np.delete(cannabis, imalos,0)

tobacco = np.loadtxt('tobacco(copia).txt',dtype=int, usecols=(0,1,2))
tobacco =np.matrix(tobacco)
tobacco=np.delete(tobacco, imalos,0)

# %%
cannabis1 = []
nodos = list(g1.nodes())

for k in range(len(nodos)):
    cannabis1.append(cannabis[k,0])
    
cannabis2 = []

for k in range(len(nodos)):
    cannabis2.append(cannabis[k,1])
    
    
cannabis3 = []

for k in range(len(nodos)):
    cannabis3.append(cannabis[k,2])
    
    
dictcannabis1 = dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dictcannabis1.update({nodos[i] : cannabis1[i]})
    

dictcannabis2 = dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dictcannabis2.update({nodos[i] : cannabis2[i]})
    

dictcannabis3= dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dictcannabis3.update({nodos[i] : cannabis3[i]})

# %% [markdown]
# # CANNABIS

# %%
def color(g):
    if g==0:
        col='brown'
    if g==1:
        col='black'
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        col='palegreen'
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        col='lightgreen'
    elif g==4:                   # definimos una funcion para asignar un color distinto a cada genero
        col='green'
    return col

# %%
def size(g):
    base = 150
    if g==0:
        size=base*1
    if g==1:
        size=base*2
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        size=base*4
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base*8
    elif g==4:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base * 14
    return size

# %%
no = mlines.Line2D([], [], color='brown', marker='o', linestyle='None',
                          markersize=15, label='No contesta')
poco = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
                          markersize=15, label='No consume')
medio = mlines.Line2D([], [], color='palegreen', marker='o', linestyle='None',
                          markersize=15, label='1 vez')

mediomedio = mlines.Line2D([], [], color='lightgreen', marker='o', linestyle='None',
                          markersize=15, label='Ocacional')
alto = mlines.Line2D([], [], color='green', marker='o', linestyle='None',
                          markersize=15, label='Regular')

# %%
AssignConsumption(g1,dictcannabis1)        

#type(dictcannabis1)

# %%
AssignConsumption(g1,dictcannabis1)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g1,'consumption').values()])

plt.legend(handles=[no,poco,medio,mediomedio,alto],prop={'size': 20},loc=3)

plt.show()

# %%
AssignConsumption(g2,dictcannabis2)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g2, 
        pos = pos, 
        node_list = g2.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g2,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g2,'consumption').values()])

#plt.legend(handles=[no,poco,medio,mediomedio,alto,altoalto],prop={'size': 20},loc=3)

#plt.show()

# %%
AssignConsumption(g3,dictcannabis3)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g3, 
        pos = pos, 
        node_list = g3.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g3,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g3,'consumption').values()])

#plt.legend(handles=[no,poco,medio,mediomedio,alto,altoalto],prop={'size': 20},loc=3)

#plt.show()

# %% [markdown]
# # TABACO

# %%
tobacco1 = []
nodos = list(g1.nodes())

for k in range(len(nodos)):
    tobacco1.append(tobacco[k,0])
    
tobacco2 = []

for k in range(len(nodos)):
    tobacco2.append(tobacco[k,1])
    
    
tobacco3 = []

for k in range(len(nodos)):
    tobacco3.append(tobacco[k,2])
    

dicttobacco1 = dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dicttobacco1.update({nodos[i] : tobacco1[i]})
    

dicttobacco2 = dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dicttobacco2.update({nodos[i] : tobacco2[i]})
    

dicttobacco3 = dict()
for i in range(len(nodos)):
    #print({nodos[i] : alcohol1[i]})
    dicttobacco3.update({nodos[i] : tobacco3[i]})

# %%
max(tobacco3)
# Out:
# 3

# %%
def color(g):
    if g==0:
        col='brown'
    if g==1:
        col='black'
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        col='plum'
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        col='purple'
    return col

# %%
def size(g):
    base = 150
    if g==0:
        size=base*1
    if g==1:
        size=base*2
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        size=base*4
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base*8
    return size

# %%
no = mlines.Line2D([], [], color='brown', marker='o', linestyle='None',
                          markersize=15, label='No contesta')
poco = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
                          markersize=15, label='No consume')
medio = mlines.Line2D([], [], color='plum', marker='o', linestyle='None',
                          markersize=15, label='Ocacional')
mediomedio = mlines.Line2D([], [], color='purple', marker='o', linestyle='None',
                          markersize=15, label='Regular')

# %%
AssignConsumption(g1,dicttobacco1)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g1,'consumption').values()])

plt.legend(handles=[no,poco,medio,mediomedio],prop={'size': 20},loc=3)

plt.show()

# %%
AssignConsumption(g2,dicttobacco2)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g2, 
        pos = pos, 
        node_list = g2.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g2,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g2,'consumption').values()])

# %%
AssignConsumption(g3,dicttobacco3)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g3, 
        pos = pos, 
        node_list = g3.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g3,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g3,'consumption').values()])

# %% [markdown]
# # INFLUENCERS

# %%
max = 11 
min = 0
primero = dict(g1.in_degree())
segundo = dict(g2.in_degree())
tercero = dict(g3.in_degree())


#como son muchos valores vamos a tomar un criterio del tipo que si vale entre tales valores es influencer bajo, medio y alto 
#dict(g1.in_degree()).values()
#pensamos que cada uno puede elegir a 6 amigos
#influencer bajo 1, por debajo de la mitad de la que pueden elegir 
def influenciar(primero):
    for key, value in primero.items():
        if 0 <= value <= 3: 
            primero[key] = 1
        if 4 <= value <= 6: 
            primero[key] = 2   
        if 6 < value <= 9: 
            primero[key] = 3
        if 9 < value <= 11:
            primero[key] = 4
    return primero

# %%
primero = influenciar(primero)
segundo = influenciar(segundo)
tercero = influenciar(tercero)

# %%
def color(g):
    if g==1:
        col='deepskyblue'
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        col='mediumspringgreen'
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        col='aqua'
    elif g==4:                   # definimos una funcion para asignar un color distinto a cada genero
        col='crimson'
    return col

# %%
def size(g):
    base = 150
    if g==1:
        size=base*2
    elif g==2:                   # definimos una funcion para asignar un color distinto a cada genero
        size=base*6
    elif g==3:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base*12
    elif g==4:                   # definimos una funcion para asignar un color distinto a cada genero
        size= base*18
    return size

# %%
no = mlines.Line2D([], [], color='deepskyblue', marker='o', linestyle='None',
                          markersize=15, label='Influencia baja')
poco = mlines.Line2D([], [], color='mediumspringgreen', marker='o', linestyle='None',
                          markersize=15, label='Influencia media')
medio = mlines.Line2D([], [], color='aqua', marker='o', linestyle='None',
                          markersize=15, label='Influencia alta')

alto = mlines.Line2D([], [], color='crimson', marker='o', linestyle='None',
                          markersize=15, label='Influencia muy alta')

# %%
AssignConsumption(g1,primero)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g1,'consumption').values()])

plt.legend(handles=[no,poco,medio, alto],prop={'size': 20},loc=3)

plt.show()

# %%
AssignConsumption(g2,segundo)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g2, 
        pos = pos, 
        node_list = g2.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g2,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g2,'consumption').values()])

#plt.legend(handles=[no,poco,medio],prop={'size': 20},loc=3)

#plt.show()

# %%
AssignConsumption(g3,tercero)        

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
 


nx.draw(G = g3, 
        pos = pos, 
        node_list = g3.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g3,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g3,'consumption').values()])

# %% [markdown]
# # PRUEBAS

# %%
plt.figure(figsize=(15,10))

#asigno atributo
AssignConsumption(g1,dictAlcohol1)  

nx.draw_networkx_nodes(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =[size(g) for g in nx.get_node_attributes(g1,'consumption').values()] )

# %%
AssignConsumption(g1,dictAlcohol2)  


plt.figure(figsize=(15,10))

nx.draw_networkx_nodes(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        edge_size = 0,
        node_size =300)

# %%
#options = {'node_color':[color(g) for g in nx.get_node_attributes(g1,'consumption').values()],
#           'node_size':300,'with_labels':False}
AssignConsumption(g1,dictAlcohol2)  

plt.figure(figsize=(15,10))
#nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])


nx.draw(G = g1, 
        pos = pos, 
        node_list = g1.nodes(), 
        node_color = [color(g) for g in nx.get_node_attributes(g1,'consumption').values()], 
        alpha = 0.8, 
        node_size =300)

# %%
#pareceria qeu algunos dejaron de tomar... me pregunto que onda

# %%
alcohol
# Out:
# matrix([[3, 1, 3],
#         [0, 0, 0],
#         [2, 2, 2],
#         [2, 2, 3],
#         [2, 3, 3],
#         [3, 2, 5],
#         [2, 3, 3],
#         [2, 2, 2],
#         [0, 3, 3],
#         [2, 3, 2],
#         [3, 3, 4],
#         [4, 4, 4],
#         [2, 3, 2],
#         [2, 3, 3],
#         [4, 0, 3],
#         [2, 0, 2],
#         [4, 5, 4],
#         [2, 2, 2],
#         [0, 0, 0],
#         [0, 2, 2],
#         [0, 0, 0],
#         [2, 0, 2],
#         [4, 5, 4],
#         [5, 5, 5],
#         [5, 5, 5],
#         [3, 0, 2],
#         [2, 3, 3],
#         [3, 4, 3],
#         [4, 4, 5],
#         [2, 3, 2],
#         [3, 3, 4],
#         [0, 2, 3],
#         [0, 0, 2],
#         [0, 2, 2],
#         [4, 5, 4],
#         [2, 2, 4],
#         [2, 4, 4],
#         [3, 3, 5],
#         [3, 3, 4],
#         [4, 3, 3],
#         [1, 1, 4],
#         [0, 0, 3],
#         [3, 4, 4],
#         [0, 4, 4],
#         [3, 3, 3],
#         [3, 5, 5],
#         [3, 4, 3],
# ...

# %%
#antes de poder dejar fijos los nodos 
AssignConsumption(g1,dictAlcohol2)  
options = {'node_color':[color(g) for g in nx.get_node_attributes(g1,'consumption').values()],
           'node_size':300,'with_labels':False}

plt.figure(figsize=(15,10))
nx.draw_spring(g1, **options)

#nx.draw(g3,pos,node_size=400,node_color='y',with_labels=True)
#(G[, dim, k, pos, fixed, ...])
