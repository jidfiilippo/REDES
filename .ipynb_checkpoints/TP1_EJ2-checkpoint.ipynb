# %%
#paquetes 
import numpy as np
import networkx as nx
import matplotlib.pylab as plt
# %matplotlib inline
import os

# %%
G = nx.read_gml('dolphins.gml')

# %%
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

# %%
gender=[j for (i,j) in dolphinsGender]

# %%
G.nodes
# Out:
# NodeView(('Beak', 'Beescratch', 'Bumper', 'CCL', 'Cross', 'DN16', 'DN21', 'DN63', 'Double', 'Feather', 'Fish', 'Five', 'Fork', 'Gallatin', 'Grin', 'Haecksel', 'Hook', 'Jet', 'Jonah', 'Knit', 'Kringel', 'MN105', 'MN23', 'MN60', 'MN83', 'Mus', 'Notch', 'Number1', 'Oscar', 'Patchback', 'PL', 'Quasi', 'Ripplefluke', 'Scabs', 'Shmuddel', 'SMN5', 'SN100', 'SN4', 'SN63', 'SN89', 'SN9', 'SN90', 'SN96', 'Stripes', 'Thumper', 'Topless', 'TR120', 'TR77', 'TR82', 'TR88', 'TR99', 'Trigger', 'TSN103', 'TSN83', 'Upbang', 'Vau', 'Wave', 'Web', 'Whitetip', 'Zap', 'Zig', 'Zipfel'))

# %%
nx.draw_circular(G, node_color=['blue' if g=='m' else 'red' for g in gender],with_labels=True)

# %%
dolphinsGender=ldata('dolphinsGender.txt')
#dolphinsGender

# %%
dolphinsGender
# Out:
# [['Beak', 'm'],
#  ['Beescratch', 'm'],
#  ['Bumper', 'm'],
#  ['CCL', 'f'],
#  ['Cross', 'm'],
#  ['DN16', 'f'],
#  ['DN21', 'm'],
#  ['DN63', 'm'],
#  ['Double', 'f'],
#  ['Feather', 'm'],
#  ['Fish', 'f'],
#  ['Five', 'f'],
#  ['Fork', 'm'],
#  ['Gallatin', 'm'],
#  ['Grin', 'm'],
#  ['Haecksel', 'm'],
#  ['Hook', 'f'],
#  ['Jet', 'm'],
#  ['Jonah', 'm'],
#  ['Knit', 'm'],
#  ['Kringel', 'f'],
#  ['MN105', 'm'],
#  ['MN23', 'm'],
#  ['MN60', 'm'],
#  ['MN83', 'm'],
#  ['Mus', 'm'],
#  ['Notch', 'm'],
#  ['Number1', 'm'],
#  ['Oscar', 'm'],
#  ['PL', 'm'],
#  ['Patchback', 'm'],
#  ['Quasi', 'm'],
#  ['Ripplefluke', 'NA'],
#  ['SMN5', 'm'],
#  ['SN100', 'f'],
#  ['SN4', 'f'],
#  ['SN63', 'f'],
#  ['SN89', 'f'],
#  ['SN9', 'f'],
#  ['SN90', 'm'],
#  ['SN96', 'm'],
#  ['Scabs', 'f'],
#  ['Shmuddel', 'f'],
#  ['Stripes', 'f'],
#  ['TR120', 'f'],
#  ['TR77', 'f'],
#  ['TR82', 'NA'],
#  ['TR88', 'f'],
#  ['TR99', 'f'],
#  ['TSN103', 'f'],
#  ['TSN83', 'NA'],
#  ['Thumper', 'm'],
#  ['Topless', 'm'],
#  ['Trigger', 'f'],
#  ['Upbang', 'm'],
#  ['Vau', 'f'],
#  ['Wave', 'f'],
#  ['Web', 'm'],
#  ['Whitetip', 'f'],
#  ['Zap', 'NA'],
#  ['Zig', 'm'],
#  ['Zipfel', 'm']]

# %%
dict_gender = {dolphin_nombre : genero for dolphin_nombre, genero  in dolphinsGender}

# %%
for n in G.nodes:
    G.nodes[n]["gender"] = dict_gender[n]

# %%
nx.get_node_attributes(G,'gender')
# Out:
# {'Beak': 'm',
#  'Beescratch': 'm',
#  'Bumper': 'm',
#  'CCL': 'f',
#  'Cross': 'm',
#  'DN16': 'f',
#  'DN21': 'm',
#  'DN63': 'm',
#  'Double': 'f',
#  'Feather': 'm',
#  'Fish': 'f',
#  'Five': 'f',
#  'Fork': 'm',
#  'Gallatin': 'm',
#  'Grin': 'm',
#  'Haecksel': 'm',
#  'Hook': 'f',
#  'Jet': 'm',
#  'Jonah': 'm',
#  'Knit': 'm',
#  'Kringel': 'f',
#  'MN105': 'm',
#  'MN23': 'm',
#  'MN60': 'm',
#  'MN83': 'm',
#  'Mus': 'm',
#  'Notch': 'm',
#  'Number1': 'm',
#  'Oscar': 'm',
#  'PL': 'm',
#  'Patchback': 'm',
#  'Quasi': 'm',
#  'Ripplefluke': 'NA',
#  'SMN5': 'm',
#  'SN100': 'f',
#  'SN4': 'f',
#  'SN63': 'f',
#  'SN89': 'f',
#  'SN9': 'f',
#  'SN90': 'm',
#  'SN96': 'm',
#  'Scabs': 'f',
#  'Shmuddel': 'f',
#  'Stripes': 'f',
#  'TR120': 'f',
#  'TR77': 'f',
#  'TR82': 'NA',
#  'TR88': 'f',
#  'TR99': 'f',
#  'TSN103': 'f',
#  'TSN83': 'NA',
#  'Thumper': 'm',
#  'Topless': 'm',
#  'Trigger': 'f',
#  'Upbang': 'm',
#  'Vau': 'f',
#  'Wave': 'f',
#  'Web': 'm',
#  'Whitetip': 'f',
#  'Zap': 'NA',
#  'Zig': 'm',
#  'Zipfel': 'm'}

# %%
nx.draw(G, node_color=['blue' if g=='m' else 'red' for g in nx.get_node_attributes(G,'gender').values()],node_size=60,with_labels=True)

# %%
# hay que agregar un color nuevo para los 'NA'
