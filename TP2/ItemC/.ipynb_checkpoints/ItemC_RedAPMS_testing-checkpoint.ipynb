# %%
import numpy as np
import networkx as nx
import matplotlib.pylab as plt
# %matplotlib inline
import os
from random import shuffle
import math
import pandas as pd
from scipy import optimize

# %% [markdown]
# # RED AP-MS

# %%
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

def grafo(datosRed):
    G = nx.Graph()
    for i in range(np.shape(datosRed)[0]):
        G.add_edges_from([(datosRed[i][0],datosRed[i][1])])
    return G

# %%
APMS = ldata('yeast_AP-MS.txt')
GAPMS = grafo(APMS)

Y2H=ldata('yeast_Y2H.txt')
GY2H=grafo(Y2H)

LIT=ldata('yeast_LIT.txt')
GLIT=grafo(LIT)

LIT_R=ldata('yeast_LIT_Reguly.txt')
GLIT_R=grafo(LIT_R)

# %% [markdown]
# # Calculo coeficientes de centralidad

# %%
# degrees=dict(Gc.degree())
# eigenvectors=nx.eigenvector_centrality_numpy(Gc)
#subgraph= nx.subgraph_centrality(G)
#shortpath=nx.betweenness_centrality(Gc)
#currentflow=nx.current_flow_betweenness_centrality(Gc)

def param(G):
   #parametros=[dict(G.degree()),nx.subgraph_centrality(G),nx.betweenness_centrality(G)] #,nx.current_flow_betweenness_centrality(G)]  
    parametros=[nx.current_flow_betweenness_centrality(G)]
    return parametros

# %%
#FUNCIÓN QUE ORDENA LOS NODOS DE MANERA DECRECIENTE SEGÚN PARÁMETRO DEL 'CRITERIO'
def ordenanodos(criterio): #criterio=diccionario 'nombredenodo':valor de parametro
    parametro=criterio.values()
    parametroordenado=sorted(set(parametro),reverse=True)
    nodosordenados=[]
    for j in parametroordenado:
        for key,value in criterio.items():
            if value==j:
                nodosordenados.append(key)
    return(nodosordenados)

# %% [markdown]
# # DESARM

# %%
def desarm(G):

    FN=[]
    LGC=[]
    
    Gc = max(nx.connected_component_subgraphs(G), key=len)
    parametros=param(Gc)
    
    for k in range(len(parametros)):
        parametro=parametros[k]
              
        Pimp=ordenanodos(parametro)
        GcDesarmable = max(nx.connected_component_subgraphs(G), key=len) #Me creo una copia de la componente Gigante Original.
        LengthOriginalGc=len(Gc)
        LargestGc=[]
        
        for i in range(len(Gc)):
            GcDesarmable.remove_node(Pimp[0])
            LargestGc.append(float(len(max(nx.connected_component_subgraphs(GcDesarmable), key=len)))/LengthOriginalGc)
            GcDesarmable = max(nx.connected_component_subgraphs(GcDesarmable), key=len)
            
            parametro=param(GcDesarmable)[k]
            Pimp=ordenanodos(parametro)
            print('lenGc',len(GcDesarmable))
            if k==len(parametros)-1:
                if len(GcDesarmable)<10:
                    it=i
                    break
            
            else:
                if len(GcDesarmable)==1:
                    it=i
                    break
                
        FN.append(np.linspace(1,it+1,it+1)/LengthOriginalGc)
        LGC.append(LargestGc)
    
    return FN,LGC

# %%
FN_APMS,LGC_APMS=desarm(GAPMS)
FN_Y2H,LGC_Y2H=desarm(GY2H)
FN_LIT,LGC_LIT=desarm(GLIT)
FN_LIT_R,LGC_LIT_r=desarm(GLIT_R)
# Out:
# lenGc 1003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-81b707d82481> in <module>()
# ----> 1 FN_APMS,LGC_APMS=desarm(GAPMS)
#       2 FN_Y2H,LGC_Y2H=desarm(GY2H)
#       3 FN_LIT,LGC_LIT=desarm(GLIT)
#       4 FN_LIT_R,LGC_LIT_r=desarm(GLIT_R)
#
# <ipython-input-7-8ac775d4af24> in desarm(G)
#      20             GcDesarmable = max(nx.connected_component_subgraphs(GcDesarmable), key=len)
#      21
# ---> 22             parametro=param(GcDesarmable)[k]
#      23             Pimp=ordenanodos(parametro)
#      24             print('lenGc',len(GcDesarmable))
#
# <ipython-input-25-6fdc398d9596> in param(G)
#       7 def param(G):
#       8    #parametros=[dict(G.degree()),nx.subgraph_centrality(G),nx.betweenness_centrality(G)] #,nx.current_flow_betweenness_centrality(G)]
# ----> 9     parametros=[nx.current_flow_betweenness_centrality(G)]
#      10     return parametros
#
# <decorator-gen-188> in current_flow_betweenness_centrality(G, normalized, weight, dtype, solver)
#
# ~/anaconda3/lib/python3.6/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# ~/anaconda3/lib/python3.6/site-packages/networkx/algorithms/centrality/current_flow_betweenness.py in current_flow_betweenness_centrality(G, normalized, weight, dtype, solver)
#     229         pos = dict(zip(row.argsort()[::-1], range(n)))
#     230         for i in range(n):
# --> 231             betweenness[s] += (i - pos[i]) * row[i]
#     232             betweenness[t] += (n - i - 1 - pos[i]) * row[i]
#     233     if normalized:
#
# KeyboardInterrupt:

# %%
# plt.plot(FN[0],LGC[0],label='degree')
# plt.plot(FN[1],LGC[1],label='shortest_path')
# plt.plot(FN[2],LGC[2],label='subgraph')
# plt.plot(FN[3],LGC[3],label='current_flow')
# plt.plot(FN[3],LGC[3],label='eigenvector')
plt.xlabel('Fraction of nodes')
plt.ylabel('Largest Giant Component')
plt.legend()

# %%
plt.plot(FN_APMS[0],LGC_APMS[0],label='APMS')
plt.plot(FN_Y2H[0],LGC_Y2H[0],label='Y2H')
plt.plot(FN_LIT[0],LGC_LIT[0],label='Literatura')
plt.plot(FN_LIT_R[0],LGC_LIT_r[0],label='Lit Reguly')
# plt.plot(FN[3],LGC[3],label='eigenvector')
plt.xlabel('Fraction of nodes')
plt.ylabel('Largest Giant Component')
plt.legend()

# %%
RandomAPMS=np.zeros((len(FN_R_APMS),2))
RandomAPMS[:,0]=FN_R_APMS
RandomAPMS[:,1]=LGC_R_APMS

RandomY2H=np.zeros((len(FN_R_Y2H),2))
RandomY2H[:,0]=FN_R_Y2H
RandomY2H[:,1]=LGC_R_Y2H

RandomLIT=np.zeros((len(FN_R_LIT),2))
RandomLIT[:,0]=FN_R_LIT
RandomLIT[:,1]=LGC_R_LIT

RandomLIT_R=np.zeros((len(FN_R_LIT_R),2))
RandomLIT_R[:,0]=FN_R_LIT_R
RandomLIT_R[:,1]=LGC_R_LIT_r

# %%
np.savetxt('RandomAPMS.txt', RandomAPMS, delimiter=',')
np.savetxt('RandomY2H.txt', RandomY2H, delimiter=',')
np.savetxt('RandomLIT.txt', RandomLIT, delimiter=',')
np.savetxt('RandomLIT_R.txt', RandomLIT_R, delimiter=',')

# %%
EigenAPMS=np.loadtxt('EigenAPMS.txt',delimiter=',')
EigenY2H=np.loadtxt('EigenY2H.txt',delimiter=',')
EigenLIT=np.loadtxt('EigenLIT.txt',delimiter=',')
EigenLIT_R=np.loadtxt('EigenLIT_R.txt',delimiter=',')

# %% [markdown]
# # Saco los nodos esenciales de mi componente gigante

# %%
essentiality=ldata('Essential.txt')

ess=[]
for i in range(len(essentiality)):
    ess.append(essentiality[i][1])
    
def essentiality(nodo): 
    if len({nodo}.intersection(set(ess)))==0:
        e=0
    else:
        e=1
    return e   

def AssignEssentiality(G,dict_ess):
    for n in G.nodes:
        G.nodes[n]["essentiality"] = dict_ess[n]
    return

def NodosEsenciales(G):
    dict_ess = { nodo: essentiality(nodo) for nodo  in G.nodes() }
    AssignEssentiality(G,dict_ess)
    nodosesenciales=[]
    for nodo in list(set(G.nodes())):
        if G.nodes.data("essentiality")[nodo]==1:
            nodosesenciales.append(nodo)
    return(nodosesenciales)

def SinEsenciales(G):
    GcEsencial = max(nx.connected_component_subgraphs(G), key=len) #Me creo una copia de la componente Gigante Original.
    LengthOriginalGc=len(max(nx.connected_component_subgraphs(G), key=len))
    nodosesenciales=NodosEsenciales(GcEsencial)
    for nodo in nodosesenciales:
        GcEsencial.remove_node(nodo)
    FN=float(len(nodosesenciales))/LengthOriginalGc
    LGC=float(len(max(nx.connected_component_subgraphs(GcEsencial), key=len)))/LengthOriginalGc
    return FN,LGC

# %%
FN_E_APMS,LGC_E_APMS=SinEsenciales(GAPMS)
FN_E_Y2H,LGC_E_Y2H=SinEsenciales(GY2H)
FN_E_LIT,LGC_E_LIT=SinEsenciales(GLIT)
FN_E_LIT_R,LGC_E_LIT_R=SinEsenciales(GLIT_R)

# %%
EfectoEsencial=np.zeros((4,2))
EfectoEsencial[0,0]=FN_E_APMS
EfectoEsencial[0,1]=LGC_E_APMS
EfectoEsencial[1,0]=FN_E_Y2H
EfectoEsencial[1,1]=LGC_E_Y2H
EfectoEsencial[2,0]=FN_E_LIT
EfectoEsencial[2,1]=LGC_E_LIT
EfectoEsencial[3,0]=FN_E_LIT_R
EfectoEsencial[3,1]=LGC_E_LIT_R

np.savetxt('EfectoEsencial.txt', EfectoEsencial, delimiter=',')

# %% [markdown]
# # Saco de manera RANDOM

# %%
def Random(G):
    GcRandom = max(nx.connected_component_subgraphs(G), key=len) #Me creo una copia de la componente Gigante Original.
    LengthOriginalGc=len(max(nx.connected_component_subgraphs(G), key=len))
    nodosrandom=np.random.permutation(list(GcRandom.nodes()))
    LGC=[]
    for nodo in nodosrandom:
        if len({nodo}.intersection(GcRandom.nodes()))==1:
            GcRandom.remove_node(nodo)
            LGC.append(float(len(max(nx.connected_component_subgraphs(GcRandom), key=len)))/LengthOriginalGc)
            GcRandom = max(nx.connected_component_subgraphs(GcRandom), key=len)          
            print('lenGc',len(GcRandom))
        if len(GcRandom)<10:
            it=len(LGC)-1
            break
    FN=np.linspace(1,it+1,it+1)/LengthOriginalGc
    return FN,LGC

# %%
FN_R_APMS,LGC_R_APMS=Random(GAPMS)
FN_R_Y2H,LGC_R_Y2H=Random(GY2H)
FN_R_LIT,LGC_R_LIT=Random(GLIT)
FN_R_LIT_R,LGC_R_LIT_r=Random(GLIT_R)
# Out:
# lenGc 1003
# lenGc 1002
# lenGc 1001
# lenGc 1000
# lenGc 999
# lenGc 998
# lenGc 997
# lenGc 996
# lenGc 995
# lenGc 994
# lenGc 993
# lenGc 992
# lenGc 991
# lenGc 990
# lenGc 989
# lenGc 988
# lenGc 987
# lenGc 958
# lenGc 957
# lenGc 956
# lenGc 954
# lenGc 953
# lenGc 952
# lenGc 951
# lenGc 950
# lenGc 949
# lenGc 947
# lenGc 946
# lenGc 945
# lenGc 944
# lenGc 943
# lenGc 942
# lenGc 939
# lenGc 938
# lenGc 937
# lenGc 936
# lenGc 935
# lenGc 934
# lenGc 933
# lenGc 932
# lenGc 931
# lenGc 930
# lenGc 929
# lenGc 928
# lenGc 927
# lenGc 926
# lenGc 925
# lenGc 924
# lenGc 923
# lenGc 922
# lenGc 921
# lenGc 920
# lenGc 919
# lenGc 918
# lenGc 915
# lenGc 914
# lenGc 913
# lenGc 912
# lenGc 911
# lenGc 910
# lenGc 909
# lenGc 905
# lenGc 904
# lenGc 903
# lenGc 902
# lenGc 901
# lenGc 900
# lenGc 899
# lenGc 898
# lenGc 897
# lenGc 896
# lenGc 895
# lenGc 894
# lenGc 893
# lenGc 892
# lenGc 891
# lenGc 890
# lenGc 889
# lenGc 888
# lenGc 887
# lenGc 884
# lenGc 883
# lenGc 882
# lenGc 880
# lenGc 879
# lenGc 878
# lenGc 877
# lenGc 876
# lenGc 875
# lenGc 874
# lenGc 873
# lenGc 872
# lenGc 871
# lenGc 869
# lenGc 868
# lenGc 867
# lenGc 866
# lenGc 865
# lenGc 863
# lenGc 862
# lenGc 861
# lenGc 859
# lenGc 857
# lenGc 856
# lenGc 855
# lenGc 854
# lenGc 853
# lenGc 852
# lenGc 851
# lenGc 850
# lenGc 849
# lenGc 839
# lenGc 838
# lenGc 835
# lenGc 834
# lenGc 832
# lenGc 831
# lenGc 830
# lenGc 829
# lenGc 826
# lenGc 825
# lenGc 824
# lenGc 823
# lenGc 822
# lenGc 821
# lenGc 820
# lenGc 817
# lenGc 816
# lenGc 810
# lenGc 801
# lenGc 800
# lenGc 799
# lenGc 798
# lenGc 797
# lenGc 796
# lenGc 795
# lenGc 794
# lenGc 793
# lenGc 792
# lenGc 791
# lenGc 790
# lenGc 789
# lenGc 788
# lenGc 787
# lenGc 783
# lenGc 782
# lenGc 781
# lenGc 780
# lenGc 779
# lenGc 778
# lenGc 777
# lenGc 776
# lenGc 775
# lenGc 774
# lenGc 773
# lenGc 772
# lenGc 771
# lenGc 770
# lenGc 768
# lenGc 767
# lenGc 764
# lenGc 763
# lenGc 762
# lenGc 761
# lenGc 760
# lenGc 759
# lenGc 758
# lenGc 757
# lenGc 756
# lenGc 753
# lenGc 752
# lenGc 751
# lenGc 750
# lenGc 749
# lenGc 748
# lenGc 746
# lenGc 745
# lenGc 744
# lenGc 743
# lenGc 737
# lenGc 736
# lenGc 735
# lenGc 734
# lenGc 733
# lenGc 732
# lenGc 731
# lenGc 730
# lenGc 729
# lenGc 728
# lenGc 727
# lenGc 726
# lenGc 725
# lenGc 724
# lenGc 723
# lenGc 722
# lenGc 714
# lenGc 713
# lenGc 711
# lenGc 710
# lenGc 709
# lenGc 708
# lenGc 707
# lenGc 703
# lenGc 702
# lenGc 701
# lenGc 700
# lenGc 699
# lenGc 698
# lenGc 697
# lenGc 696
# lenGc 695
# lenGc 694
# lenGc 693
# lenGc 692
# lenGc 691
# lenGc 690
# lenGc 689
# lenGc 688
# lenGc 687
# lenGc 686
# lenGc 685
# lenGc 684
# lenGc 683
# lenGc 682
# lenGc 681
# lenGc 679
# lenGc 678
# lenGc 677
# lenGc 676
# lenGc 675
# lenGc 674
# lenGc 673
# lenGc 656
# lenGc 655
# lenGc 654
# lenGc 653
# lenGc 649
# lenGc 648
# lenGc 647
# lenGc 646
# lenGc 645
# lenGc 644
# lenGc 643
# lenGc 642
# lenGc 641
# lenGc 640
# lenGc 639
# lenGc 638
# lenGc 637
# lenGc 635
# lenGc 634
# lenGc 633
# lenGc 632
# lenGc 631
# lenGc 630
# lenGc 629
# lenGc 628
# lenGc 621
# lenGc 619
# lenGc 591
# lenGc 590
# lenGc 589
# lenGc 588
# lenGc 581
# lenGc 580
# lenGc 579
# lenGc 578
# lenGc 576
# lenGc 575
# lenGc 574
# lenGc 573
# lenGc 572
# lenGc 571
# lenGc 566
# lenGc 565
# lenGc 564
# lenGc 563
# lenGc 562
# lenGc 561
# lenGc 560
# lenGc 559
# lenGc 558
# lenGc 557
# lenGc 556
# lenGc 555
# lenGc 554
# lenGc 553
# lenGc 552
# lenGc 551
# lenGc 550
# lenGc 549
# lenGc 548
# lenGc 547
# lenGc 546
# lenGc 545
# lenGc 544
# lenGc 543
# lenGc 542
# lenGc 541
# lenGc 540
# lenGc 536
# lenGc 534
# lenGc 533
# lenGc 527
# lenGc 526
# lenGc 525
# lenGc 524
# lenGc 523
# lenGc 522
# lenGc 521
# lenGc 520
# lenGc 519
# lenGc 512
# lenGc 511
# lenGc 510
# lenGc 509
# lenGc 508
# lenGc 507
# lenGc 506
# lenGc 505
# lenGc 504
# lenGc 503
# lenGc 500
# lenGc 499
# lenGc 498
# lenGc 497
# lenGc 496
# lenGc 495
# lenGc 494
# lenGc 491
# lenGc 490
# lenGc 489
# lenGc 488
# lenGc 487
# lenGc 486
# lenGc 485
# lenGc 484
# lenGc 483
# lenGc 481
# lenGc 480
# lenGc 478
# lenGc 477
# lenGc 476
# lenGc 475
# lenGc 474
# lenGc 473
# lenGc 472
# lenGc 471
# lenGc 470
# lenGc 469
# lenGc 468
# lenGc 467
# lenGc 466
# lenGc 465
# lenGc 464
# lenGc 463
# lenGc 462
# lenGc 461
# lenGc 460
# lenGc 459
# lenGc 458
# lenGc 456
# lenGc 450
# lenGc 449
# lenGc 448
# lenGc 447
# lenGc 446
# lenGc 445
# lenGc 444
# lenGc 443
# lenGc 442
# lenGc 441
# lenGc 440
# lenGc 439
# lenGc 437
# lenGc 433
# lenGc 432
# lenGc 431
# lenGc 430
# lenGc 429
# lenGc 428
# lenGc 427
# lenGc 426
# lenGc 425
# lenGc 424
# lenGc 422
# lenGc 421
# lenGc 418
# lenGc 413
# lenGc 412
# lenGc 408
# lenGc 407
# lenGc 406
# lenGc 404
# lenGc 403
# lenGc 402
# lenGc 400
# lenGc 399
# lenGc 398
# lenGc 397
# lenGc 396
# lenGc 361
# lenGc 360
# lenGc 359
# lenGc 358
# lenGc 357
# lenGc 356
# lenGc 355
# lenGc 354
# lenGc 353
# lenGc 352
# lenGc 348
# lenGc 347
# lenGc 346
# lenGc 345
# lenGc 337
# lenGc 336
# lenGc 335
# lenGc 334
# lenGc 333
# lenGc 332
# lenGc 331
# lenGc 241
# lenGc 240
# lenGc 239
# lenGc 237
# lenGc 236
# lenGc 235
# lenGc 234
# lenGc 233
# lenGc 232
# lenGc 231
# lenGc 230
# lenGc 221
# lenGc 220
# lenGc 219
# lenGc 218
# lenGc 215
# lenGc 214
# lenGc 213
# lenGc 211
# lenGc 210
# lenGc 209
# lenGc 208
# lenGc 207
# lenGc 206
# lenGc 205
# lenGc 204
# lenGc 203
# lenGc 202
# lenGc 201
# lenGc 200
# lenGc 199
# lenGc 197
# lenGc 196
# lenGc 195
# lenGc 194
# lenGc 193
# lenGc 192
# lenGc 191
# lenGc 190
# lenGc 189
# lenGc 188
# lenGc 187
# lenGc 186
# lenGc 183
# lenGc 182
# lenGc 181
# lenGc 180
# lenGc 179
# lenGc 178
# lenGc 177
# lenGc 176
# lenGc 175
# lenGc 173
# lenGc 172
# lenGc 171
# lenGc 170
# lenGc 169
# lenGc 168
# lenGc 167
# lenGc 166
# lenGc 163
# lenGc 162
# lenGc 161
# lenGc 160
# lenGc 159
# lenGc 158
# lenGc 157
# lenGc 156
# lenGc 155
# lenGc 154
# lenGc 153
# lenGc 152
# lenGc 151
# lenGc 150
# lenGc 149
# lenGc 148
# lenGc 147
# lenGc 146
# lenGc 145
# lenGc 144
# lenGc 143
# lenGc 142
# lenGc 141
# lenGc 140
# lenGc 129
# lenGc 127
# lenGc 124
# lenGc 123
# lenGc 122
# lenGc 121
# lenGc 120
# lenGc 119
# lenGc 118
# lenGc 117
# lenGc 116
# lenGc 115
# lenGc 114
# lenGc 113
# lenGc 106
# lenGc 105
# lenGc 104
# lenGc 103
# lenGc 102
# lenGc 101
# lenGc 100
# lenGc 99
# lenGc 98
# lenGc 97
# lenGc 96
# lenGc 95
# lenGc 94
# lenGc 93
# lenGc 92
# lenGc 91
# lenGc 90
# lenGc 89
# lenGc 88
# lenGc 87
# lenGc 86
# lenGc 85
# lenGc 84
# lenGc 83
# lenGc 82
# lenGc 79
# lenGc 78
# lenGc 77
# lenGc 76
# lenGc 75
# lenGc 74
# lenGc 73
# lenGc 63
# lenGc 62
# lenGc 61
# lenGc 60
# lenGc 59
# lenGc 58
# lenGc 57
# lenGc 56
# lenGc 55
# lenGc 54
# lenGc 52
# lenGc 51
# lenGc 50
# lenGc 49
# lenGc 48
# lenGc 47
# lenGc 46
# lenGc 45
# lenGc 44
# lenGc 43
# lenGc 42
# lenGc 41
# lenGc 40
# lenGc 39
# lenGc 38
# lenGc 37
# lenGc 36
# lenGc 35
# lenGc 30
# lenGc 28
# lenGc 27
# lenGc 26
# lenGc 25
# lenGc 24
# lenGc 23
# lenGc 22
# lenGc 21
# lenGc 20
# lenGc 19
# lenGc 18
# lenGc 17
# lenGc 15
# lenGc 14
# lenGc 13
# lenGc 12
# lenGc 11
# lenGc 10
# lenGc 9
# lenGc 1645
# lenGc 1644
# lenGc 1643
# lenGc 1642
# lenGc 1641
# lenGc 1640
# lenGc 1638
# lenGc 1636
# lenGc 1633
# lenGc 1632
# lenGc 1630
# lenGc 1629
# lenGc 1624
# lenGc 1623
# lenGc 1622
# lenGc 1621
# lenGc 1619
# lenGc 1618
# lenGc 1617
# lenGc 1616
# lenGc 1615
# lenGc 1614
# lenGc 1613
# lenGc 1612
# lenGc 1611
# lenGc 1609
# lenGc 1608
# lenGc 1607
# lenGc 1606
# lenGc 1605
# lenGc 1604
# lenGc 1603
# lenGc 1602
# lenGc 1601
# lenGc 1600
# lenGc 1591
# lenGc 1589
# lenGc 1587
# lenGc 1586
# lenGc 1585
# lenGc 1584
# lenGc 1575
# lenGc 1574
# lenGc 1569
# lenGc 1568
# lenGc 1567
# lenGc 1566
# lenGc 1560
# lenGc 1559
# lenGc 1558
# lenGc 1557
# lenGc 1555
# lenGc 1554
# lenGc 1552
# lenGc 1550
# lenGc 1548
# lenGc 1546
# lenGc 1545
# lenGc 1544
# lenGc 1543
# lenGc 1542
# lenGc 1540
# lenGc 1539
# lenGc 1537
# lenGc 1536
# lenGc 1535
# lenGc 1534
# lenGc 1533
# lenGc 1518
# lenGc 1517
# lenGc 1516
# lenGc 1515
# lenGc 1512
# lenGc 1509
# lenGc 1508
# lenGc 1507
# lenGc 1500
# lenGc 1499
# lenGc 1498
# lenGc 1476
# lenGc 1475
# lenGc 1474
# lenGc 1473
# lenGc 1471
# lenGc 1469
# lenGc 1463
# lenGc 1459
# lenGc 1458
# lenGc 1457
# lenGc 1454
# lenGc 1452
# lenGc 1451
# lenGc 1449
# lenGc 1448
# lenGc 1446
# lenGc 1445
# lenGc 1444
# lenGc 1442
# lenGc 1436
# lenGc 1435
# lenGc 1434
# lenGc 1432
# lenGc 1431
# lenGc 1430
# lenGc 1429
# lenGc 1427
# lenGc 1426
# lenGc 1425
# lenGc 1411
# lenGc 1410
# lenGc 1409
# lenGc 1408
# lenGc 1407
# lenGc 1406
# lenGc 1403
# lenGc 1402
# lenGc 1401
# lenGc 1399
# lenGc 1398
# lenGc 1397
# lenGc 1394
# lenGc 1392
# lenGc 1390
# lenGc 1389
# lenGc 1388
# lenGc 1387
# lenGc 1379
# lenGc 1370
# lenGc 1369
# lenGc 1365
# lenGc 1364
# lenGc 1359
# lenGc 1358
# lenGc 1357
# lenGc 1356
# lenGc 1355
# lenGc 1354
# lenGc 1353
# lenGc 1352
# lenGc 1351
# lenGc 1346
# lenGc 1345
# lenGc 1344
# lenGc 1343
# lenGc 1341
# lenGc 1338
# lenGc 1334
# lenGc 1332
# lenGc 1331
# lenGc 1330
# lenGc 1329
# lenGc 1325
# lenGc 1324
# lenGc 1321
# lenGc 1320
# lenGc 1319
# lenGc 1318
# lenGc 1315
# lenGc 1309
# lenGc 1307
# lenGc 1306
# lenGc 1305
# lenGc 1304
# lenGc 1297
# lenGc 1296
# lenGc 1295
# lenGc 1294
# lenGc 1293
# lenGc 1292
# lenGc 1291
# lenGc 1290
# lenGc 1287
# lenGc 1286
# lenGc 1285
# lenGc 1281
# lenGc 1280
# lenGc 1279
# lenGc 1278
# lenGc 1277
# lenGc 1276
# lenGc 1275
# lenGc 1274
# lenGc 1273
# lenGc 1272
# lenGc 1271
# lenGc 1270
# lenGc 1269
# lenGc 1267
# lenGc 1266
# lenGc 1265
# lenGc 1264
# lenGc 1263
# lenGc 1262
# lenGc 1261
# lenGc 1260
# lenGc 1259
# lenGc 1258
# lenGc 1256
# lenGc 1255
# lenGc 1254
# lenGc 1253
# lenGc 1252
# lenGc 1248
# lenGc 1247
# lenGc 1246
# lenGc 1244
# lenGc 1243
# lenGc 1242
# lenGc 1241
# lenGc 1240
# lenGc 1238
# lenGc 1228
# lenGc 1227
# lenGc 1225
# lenGc 1224
# lenGc 1217
# lenGc 1216
# lenGc 1215
# lenGc 1213
# lenGc 1212
# lenGc 1210
# lenGc 1209
# lenGc 1208
# lenGc 1207
# lenGc 1205
# lenGc 1203
# lenGc 1202
# lenGc 1201
# lenGc 1200
# lenGc 1199
# lenGc 1198
# lenGc 1194
# lenGc 1193
# lenGc 1192
# lenGc 1191
# lenGc 1187
# lenGc 1186
# lenGc 1185
# lenGc 1184
# lenGc 1183
# lenGc 1182
# lenGc 1181
# lenGc 1180
# lenGc 1178
# lenGc 1177
# lenGc 1175
# lenGc 1173
# lenGc 1171
# lenGc 1170
# lenGc 1169
# lenGc 1168
# lenGc 1166
# lenGc 1165
# lenGc 1164
# lenGc 1163
# lenGc 1162
# lenGc 1155
# lenGc 1150
# lenGc 1149
# lenGc 1148
# lenGc 1144
# lenGc 1140
# lenGc 1139
# lenGc 1138
# lenGc 1137
# lenGc 1136
# lenGc 1135
# lenGc 1134
# lenGc 1133
# lenGc 1131
# lenGc 1129
# lenGc 1127
# lenGc 1126
# lenGc 1125
# lenGc 1124
# lenGc 1121
# lenGc 1120
# lenGc 1118
# lenGc 1114
# lenGc 1113
# lenGc 1112
# lenGc 1111
# lenGc 1110
# lenGc 1109
# lenGc 1108
# lenGc 1106
# lenGc 1104
# lenGc 1103
# lenGc 1100
# lenGc 1096
# lenGc 1078
# lenGc 1074
# lenGc 1071
# lenGc 1060
# lenGc 1058
# lenGc 1057
# lenGc 1056
# lenGc 1055
# lenGc 1054
# lenGc 1053
# lenGc 1052
# lenGc 1051
# lenGc 1039
# lenGc 1037
# lenGc 1036
# lenGc 1035
# lenGc 1034
# lenGc 1033
# lenGc 1032
# lenGc 1031
# lenGc 1029
# lenGc 1028
# lenGc 1027
# lenGc 1023
# lenGc 1022
# lenGc 1021
# lenGc 1020
# lenGc 1019
# lenGc 1018
# lenGc 1017
# lenGc 1016
# lenGc 1015
# lenGc 1014
# lenGc 1013
# lenGc 1010
# lenGc 1008
# lenGc 1007
# lenGc 1003
# lenGc 1002
# lenGc 1001
# lenGc 1000
# lenGc 999
# lenGc 998
# lenGc 997
# lenGc 995
# lenGc 994
# lenGc 992
# lenGc 991
# lenGc 990
# lenGc 989
# lenGc 988
# lenGc 987
# lenGc 986
# lenGc 984
# lenGc 980
# lenGc 979
# lenGc 978
# lenGc 977
# lenGc 975
# lenGc 973
# lenGc 972
# lenGc 970
# lenGc 963
# lenGc 962
# lenGc 957
# lenGc 956
# lenGc 955
# lenGc 954
# lenGc 953
# lenGc 952
# lenGc 951
# lenGc 950
# lenGc 949
# lenGc 948
# lenGc 946
# lenGc 945
# lenGc 944
# lenGc 943
# lenGc 942
# lenGc 941
# lenGc 935
# lenGc 934
# lenGc 930
# lenGc 929
# lenGc 928
# lenGc 927
# lenGc 926
# lenGc 925
# lenGc 924
# lenGc 923
# lenGc 922
# lenGc 921
# lenGc 920
# lenGc 919
# lenGc 918
# lenGc 916
# lenGc 913
# lenGc 912
# lenGc 911
# lenGc 905
# lenGc 904
# lenGc 901
# lenGc 900
# lenGc 899
# lenGc 895
# lenGc 894
# lenGc 893
# lenGc 892
# lenGc 890
# lenGc 889
# lenGc 888
# lenGc 885
# lenGc 883
# lenGc 879
# lenGc 878
# lenGc 876
# lenGc 875
# lenGc 874
# lenGc 872
# lenGc 868
# lenGc 865
# lenGc 861
# lenGc 859
# lenGc 858
# lenGc 855
# lenGc 854
# lenGc 852
# lenGc 851
# lenGc 849
# lenGc 848
# lenGc 847
# lenGc 846
# lenGc 845
# lenGc 844
# lenGc 829
# lenGc 828
# lenGc 825
# lenGc 824
# lenGc 822
# lenGc 820
# lenGc 819
# lenGc 816
# lenGc 815
# lenGc 809
# lenGc 808
# lenGc 801
# lenGc 800
# lenGc 799
# lenGc 798
# lenGc 797
# lenGc 796
# lenGc 794
# lenGc 793
# lenGc 792
# lenGc 791
# lenGc 790
# lenGc 786
# lenGc 785
# lenGc 784
# lenGc 783
# lenGc 782
# lenGc 780
# lenGc 779
# lenGc 775
# lenGc 774
# lenGc 773
# lenGc 771
# lenGc 770
# lenGc 767
# lenGc 763
# lenGc 762
# lenGc 760
# lenGc 759
# lenGc 755
# lenGc 754
# lenGc 750
# lenGc 743
# lenGc 739
# lenGc 738
# lenGc 737
# lenGc 731
# lenGc 730
# lenGc 729
# lenGc 728
# lenGc 727
# lenGc 726
# lenGc 725
# lenGc 723
# lenGc 722
# lenGc 721
# lenGc 720
# lenGc 719
# lenGc 717
# lenGc 715
# lenGc 713
# lenGc 711
# lenGc 710
# lenGc 707
# lenGc 706
# lenGc 705
# lenGc 704
# lenGc 703
# lenGc 702
# lenGc 701
# lenGc 699
# lenGc 698
# lenGc 697
# lenGc 696
# lenGc 695
# lenGc 694
# lenGc 693
# lenGc 690
# lenGc 689
# lenGc 687
# lenGc 686
# lenGc 685
# lenGc 684
# lenGc 683
# lenGc 682
# lenGc 680
# lenGc 679
# lenGc 677
# lenGc 674
# lenGc 673
# lenGc 672
# lenGc 670
# lenGc 667
# lenGc 663
# lenGc 662
# lenGc 661
# lenGc 655
# lenGc 654
# lenGc 653
# lenGc 652
# lenGc 651
# lenGc 650
# lenGc 642
# lenGc 640
# lenGc 637
# lenGc 634
# lenGc 633
# lenGc 632
# lenGc 631
# lenGc 626
# lenGc 625
# lenGc 624
# lenGc 621
# lenGc 620
# lenGc 618
# lenGc 617
# lenGc 596
# lenGc 591
# lenGc 590
# lenGc 589
# lenGc 588
# lenGc 587
# lenGc 586
# lenGc 585
# lenGc 578
# lenGc 576
# lenGc 575
# lenGc 574
# lenGc 573
# lenGc 572
# lenGc 571
# lenGc 570
# lenGc 569
# lenGc 568
# lenGc 567
# lenGc 566
# lenGc 565
# lenGc 564
# lenGc 563
# lenGc 562
# lenGc 561
# lenGc 560
# lenGc 559
# lenGc 558
# lenGc 538
# lenGc 535
# lenGc 534
# lenGc 533
# lenGc 528
# lenGc 527
# lenGc 526
# lenGc 525
# lenGc 479
# lenGc 478
# lenGc 477
# lenGc 476
# lenGc 475
# lenGc 474
# lenGc 473
# lenGc 472
# lenGc 471
# lenGc 470
# lenGc 469
# lenGc 468
# lenGc 467
# lenGc 464
# lenGc 461
# lenGc 460
# lenGc 459
# lenGc 457
# lenGc 456
# lenGc 448
# lenGc 444
# lenGc 442
# lenGc 441
# lenGc 440
# lenGc 434
# lenGc 432
# lenGc 426
# lenGc 418
# lenGc 417
# lenGc 416
# lenGc 415
# lenGc 414
# lenGc 412
# lenGc 411
# lenGc 410
# lenGc 409
# lenGc 408
# lenGc 407
# lenGc 405
# lenGc 396
# lenGc 391
# lenGc 390
# lenGc 389
# lenGc 387
# lenGc 385
# lenGc 359
# lenGc 358
# lenGc 357
# lenGc 355
# lenGc 353
# lenGc 352
# lenGc 351
# lenGc 349
# lenGc 348
# lenGc 347
# lenGc 346
# lenGc 344
# lenGc 343
# lenGc 340
# lenGc 339
# lenGc 338
# lenGc 337
# lenGc 334
# lenGc 333
# lenGc 332
# lenGc 331
# lenGc 319
# lenGc 318
# lenGc 317
# lenGc 316
# lenGc 314
# lenGc 307
# lenGc 306
# lenGc 302
# lenGc 298
# lenGc 296
# lenGc 295
# lenGc 294
# lenGc 293
# lenGc 292
# lenGc 291
# lenGc 288
# lenGc 287
# lenGc 285
# lenGc 281
# lenGc 276
# lenGc 271
# lenGc 265
# lenGc 264
# lenGc 263
# lenGc 257
# lenGc 256
# lenGc 255
# lenGc 253
# lenGc 252
# lenGc 251
# lenGc 250
# lenGc 249
# lenGc 248
# lenGc 247
# lenGc 246
# lenGc 245
# lenGc 244
# lenGc 243
# lenGc 241
# lenGc 240
# lenGc 238
# lenGc 237
# lenGc 235
# lenGc 234
# lenGc 233
# lenGc 227
# lenGc 226
# lenGc 222
# lenGc 221
# lenGc 220
# lenGc 219
# lenGc 218
# lenGc 216
# lenGc 215
# lenGc 214
# lenGc 213
# lenGc 210
# lenGc 209
# lenGc 208
# lenGc 207
# lenGc 206
# lenGc 203
# lenGc 202
# lenGc 201
# lenGc 200
# lenGc 199
# lenGc 177
# lenGc 176
# lenGc 172
# lenGc 170
# lenGc 168
# lenGc 167
# lenGc 165
# lenGc 164
# lenGc 163
# lenGc 162
# lenGc 161
# lenGc 158
# lenGc 157
# lenGc 151
# lenGc 150
# lenGc 149
# lenGc 148
# lenGc 147
# lenGc 141
# lenGc 140
# lenGc 139
# lenGc 125
# lenGc 124
# lenGc 122
# lenGc 120
# lenGc 62
# lenGc 61
# lenGc 60
# lenGc 58
# lenGc 57
# lenGc 50
# lenGc 48
# lenGc 47
# lenGc 45
# lenGc 25
# lenGc 24
# lenGc 18
# lenGc 14
# lenGc 13
# lenGc 12
# lenGc 7
# lenGc 1212
# lenGc 1211
# lenGc 1210
# lenGc 1209
# lenGc 1208
# lenGc 1199
# lenGc 1198
# lenGc 1197
# lenGc 1196
# lenGc 1195
# lenGc 1194
# lenGc 1193
# lenGc 1192
# lenGc 1189
# lenGc 1188
# lenGc 1187
# lenGc 1186
# lenGc 1185
# lenGc 1184
# lenGc 1183
# lenGc 1182
# lenGc 1181
# lenGc 1180
# lenGc 1179
# lenGc 1178
# lenGc 1177
# lenGc 1176
# lenGc 1175
# lenGc 1174
# lenGc 1173
# lenGc 1172
# lenGc 1171
# lenGc 1168
# lenGc 1167
# lenGc 1166
# lenGc 1165
# lenGc 1164
# lenGc 1163
# lenGc 1159
# lenGc 1158
# lenGc 1157
# lenGc 1156
# lenGc 1155
# lenGc 1154
# lenGc 1151
# lenGc 1150
# lenGc 1149
# lenGc 1148
# lenGc 1147
# lenGc 1146
# lenGc 1145
# lenGc 1141
# lenGc 1140
# lenGc 1139
# lenGc 1135
# lenGc 1134
# lenGc 1133
# lenGc 1132
# lenGc 1131
# lenGc 1129
# lenGc 1128
# lenGc 1127
# lenGc 1126
# lenGc 1123
# lenGc 1122
# lenGc 1121
# lenGc 1120
# lenGc 1119
# lenGc 1118
# lenGc 1116
# lenGc 1115
# lenGc 1112
# lenGc 1111
# lenGc 1110
# lenGc 1109
# lenGc 1108
# lenGc 1106
# lenGc 1101
# lenGc 1100
# lenGc 1099
# lenGc 1098
# lenGc 1097
# lenGc 1096
# lenGc 1095
# lenGc 1091
# lenGc 1090
# lenGc 1089
# lenGc 1088
# lenGc 1087
# lenGc 1086
# lenGc 1085
# lenGc 1084
# lenGc 1083
# lenGc 1082
# lenGc 1081
# lenGc 1080
# lenGc 1079
# lenGc 1078
# lenGc 1077
# lenGc 1076
# lenGc 1074
# lenGc 1073
# lenGc 1072
# lenGc 1071
# lenGc 1070
# lenGc 1069
# lenGc 1068
# lenGc 1067
# lenGc 1066
# lenGc 1065
# lenGc 1064
# lenGc 1062
# lenGc 1061
# lenGc 1059
# lenGc 1058
# lenGc 1057
# lenGc 1056
# lenGc 1055
# lenGc 1054
# lenGc 1053
# lenGc 1052
# lenGc 1049
# lenGc 1048
# lenGc 1046
# lenGc 1045
# lenGc 1042
# lenGc 1041
# lenGc 1040
# lenGc 1039
# lenGc 1038
# lenGc 1037
# lenGc 1036
# lenGc 1035
# lenGc 1034
# lenGc 1033
# lenGc 1032
# lenGc 1031
# lenGc 1030
# lenGc 1025
# lenGc 1024
# lenGc 1023
# lenGc 1022
# lenGc 1021
# lenGc 1019
# lenGc 1018
# lenGc 1017
# lenGc 1016
# lenGc 1015
# lenGc 1014
# lenGc 1013
# lenGc 1012
# lenGc 1011
# lenGc 1010
# lenGc 1009
# lenGc 1003
# lenGc 1000
# lenGc 999
# lenGc 998
# lenGc 997
# lenGc 995
# lenGc 994
# lenGc 993
# lenGc 992
# lenGc 991
# lenGc 990
# lenGc 989
# lenGc 981
# lenGc 978
# lenGc 977
# lenGc 976
# lenGc 975
# lenGc 974
# lenGc 968
# lenGc 967
# lenGc 960
# lenGc 959
# lenGc 958
# lenGc 955
# lenGc 954
# lenGc 951
# lenGc 950
# lenGc 940
# lenGc 939
# lenGc 937
# lenGc 936
# lenGc 935
# lenGc 930
# lenGc 928
# lenGc 927
# lenGc 926
# lenGc 924
# lenGc 920
# lenGc 919
# lenGc 918
# lenGc 917
# lenGc 916
# lenGc 915
# lenGc 913
# lenGc 912
# lenGc 909
# lenGc 907
# lenGc 905
# lenGc 902
# lenGc 901
# lenGc 900
# lenGc 890
# lenGc 889
# lenGc 888
# lenGc 885
# lenGc 884
# lenGc 883
# lenGc 882
# lenGc 881
# lenGc 880
# lenGc 879
# lenGc 875
# lenGc 874
# lenGc 873
# lenGc 872
# lenGc 870
# lenGc 868
# lenGc 867
# lenGc 861
# lenGc 860
# lenGc 858
# lenGc 857
# lenGc 855
# lenGc 854
# lenGc 853
# lenGc 852
# lenGc 851
# lenGc 850
# lenGc 849
# lenGc 848
# lenGc 847
# lenGc 846
# lenGc 845
# lenGc 844
# lenGc 843
# lenGc 842
# lenGc 841
# lenGc 840
# lenGc 839
# lenGc 838
# lenGc 837
# lenGc 836
# lenGc 835
# lenGc 834
# lenGc 831
# lenGc 830
# lenGc 826
# lenGc 824
# lenGc 823
# lenGc 821
# lenGc 820
# lenGc 819
# lenGc 818
# lenGc 817
# lenGc 816
# lenGc 815
# lenGc 814
# lenGc 813
# lenGc 811
# lenGc 810
# lenGc 809
# lenGc 807
# lenGc 806
# lenGc 805
# lenGc 804
# lenGc 803
# lenGc 801
# lenGc 800
# lenGc 796
# lenGc 795
# lenGc 794
# lenGc 793
# lenGc 792
# lenGc 790
# lenGc 788
# lenGc 787
# lenGc 785
# lenGc 784
# lenGc 783
# lenGc 782
# lenGc 781
# lenGc 780
# lenGc 779
# lenGc 777
# lenGc 776
# lenGc 773
# lenGc 772
# lenGc 771
# lenGc 770
# lenGc 769
# lenGc 768
# lenGc 767
# lenGc 766
# lenGc 763
# lenGc 756
# lenGc 755
# lenGc 754
# lenGc 750
# lenGc 747
# lenGc 746
# lenGc 745
# lenGc 744
# lenGc 743
# lenGc 742
# lenGc 690
# lenGc 689
# lenGc 686
# lenGc 670
# lenGc 669
# lenGc 668
# lenGc 667
# lenGc 666
# lenGc 665
# lenGc 660
# lenGc 659
# lenGc 658
# lenGc 657
# lenGc 656
# lenGc 655
# lenGc 654
# lenGc 653
# lenGc 651
# lenGc 650
# lenGc 649
# lenGc 648
# lenGc 645
# lenGc 644
# lenGc 640
# lenGc 639
# lenGc 638
# lenGc 636
# lenGc 635
# lenGc 634
# lenGc 633
# lenGc 631
# lenGc 630
# lenGc 629
# lenGc 628
# lenGc 627
# lenGc 624
# lenGc 623
# lenGc 621
# lenGc 618
# lenGc 617
# lenGc 616
# lenGc 615
# lenGc 611
# lenGc 610
# lenGc 609
# lenGc 608
# lenGc 604
# lenGc 603
# lenGc 602
# lenGc 601
# lenGc 600
# lenGc 599
# lenGc 598
# lenGc 595
# lenGc 589
# lenGc 584
# lenGc 582
# lenGc 581
# lenGc 580
# lenGc 579
# lenGc 575
# lenGc 573
# lenGc 570
# lenGc 569
# lenGc 566
# lenGc 565
# lenGc 564
# lenGc 563
# lenGc 562
# lenGc 561
# lenGc 556
# lenGc 555
# lenGc 554
# lenGc 553
# lenGc 552
# lenGc 551
# lenGc 550
# lenGc 549
# lenGc 548
# lenGc 547
# lenGc 546
# lenGc 529
# lenGc 528
# lenGc 527
# lenGc 526
# lenGc 525
# lenGc 524
# lenGc 523
# lenGc 522
# lenGc 521
# lenGc 518
# lenGc 516
# lenGc 515
# lenGc 514
# lenGc 513
# lenGc 512
# lenGc 511
# lenGc 501
# lenGc 500
# lenGc 479
# lenGc 478
# lenGc 477
# lenGc 476
# lenGc 475
# lenGc 474
# lenGc 453
# lenGc 452
# lenGc 450
# lenGc 449
# lenGc 448
# lenGc 446
# lenGc 442
# lenGc 441
# lenGc 440
# lenGc 439
# lenGc 437
# lenGc 436
# lenGc 429
# lenGc 428
# lenGc 427
# lenGc 426
# lenGc 425
# lenGc 424
# lenGc 421
# lenGc 419
# lenGc 415
# lenGc 414
# lenGc 413
# lenGc 412
# lenGc 411
# lenGc 410
# lenGc 409
# lenGc 408
# lenGc 406
# lenGc 405
# lenGc 395
# lenGc 394
# lenGc 383
# lenGc 382
# lenGc 381
# lenGc 380
# lenGc 379
# lenGc 378
# lenGc 377
# lenGc 376
# lenGc 375
# lenGc 374
# lenGc 373
# lenGc 372
# lenGc 370
# lenGc 368
# lenGc 366
# lenGc 365
# lenGc 364
# lenGc 363
# lenGc 362
# lenGc 361
# lenGc 360
# lenGc 359
# lenGc 358
# lenGc 357
# lenGc 356
# lenGc 355
# lenGc 353
# lenGc 352
# lenGc 351
# lenGc 350
# lenGc 349
# lenGc 348
# lenGc 347
# lenGc 336
# lenGc 333
# lenGc 332
# lenGc 331
# lenGc 330
# lenGc 329
# lenGc 328
# lenGc 327
# lenGc 326
# lenGc 325
# lenGc 323
# lenGc 322
# lenGc 245
# lenGc 244
# lenGc 243
# lenGc 242
# lenGc 241
# lenGc 240
# lenGc 239
# lenGc 234
# lenGc 233
# lenGc 196
# lenGc 195
# lenGc 191
# lenGc 189
# lenGc 188
# lenGc 187
# lenGc 185
# lenGc 184
# lenGc 183
# lenGc 182
# lenGc 181
# lenGc 179
# lenGc 178
# lenGc 177
# lenGc 176
# lenGc 163
# lenGc 162
# lenGc 161
# lenGc 160
# lenGc 159
# lenGc 153
# lenGc 152
# lenGc 151
# lenGc 150
# lenGc 149
# lenGc 148
# lenGc 147
# lenGc 146
# lenGc 145
# lenGc 144
# lenGc 143
# lenGc 142
# lenGc 141
# lenGc 140
# lenGc 139
# lenGc 137
# lenGc 136
# lenGc 135
# lenGc 123
# lenGc 122
# lenGc 121
# lenGc 117
# lenGc 114
# lenGc 113
# lenGc 112
# lenGc 111
# lenGc 66
# lenGc 65
# lenGc 64
# lenGc 63
# lenGc 62
# lenGc 61
# lenGc 59
# lenGc 58
# lenGc 57
# lenGc 56
# lenGc 55
# lenGc 54
# lenGc 53
# lenGc 52
# lenGc 51
# lenGc 50
# lenGc 49
# lenGc 48
# lenGc 39
# lenGc 38
# lenGc 35
# lenGc 31
# lenGc 25
# lenGc 24
# lenGc 23
# lenGc 22
# lenGc 20
# lenGc 19
# lenGc 14
# lenGc 10
# lenGc 9
# lenGc 3223
# lenGc 3221
# lenGc 3220
# lenGc 3219
# lenGc 3218
# lenGc 3216
# lenGc 3215
# lenGc 3214
# lenGc 3213
# lenGc 3212
# lenGc 3211
# lenGc 3209
# lenGc 3208
# lenGc 3207
# lenGc 3206
# lenGc 3205
# lenGc 3204
# lenGc 3203
# lenGc 3200
# lenGc 3199
# lenGc 3198
# lenGc 3197
# lenGc 3195
# lenGc 3194
# lenGc 3193
# lenGc 3192
# lenGc 3191
# lenGc 3190
# lenGc 3189
# lenGc 3188
# lenGc 3187
# lenGc 3186
# lenGc 3185
# lenGc 3184
# lenGc 3183
# lenGc 3182
# lenGc 3181
# lenGc 3180
# lenGc 3179
# lenGc 3178
# lenGc 3177
# lenGc 3176
# lenGc 3175
# lenGc 3174
# lenGc 3173
# lenGc 3170
# lenGc 3169
# lenGc 3161
# lenGc 3155
# lenGc 3153
# lenGc 3152
# lenGc 3151
# lenGc 3150
# lenGc 3149
# lenGc 3147
# lenGc 3146
# lenGc 3144
# lenGc 3143
# lenGc 3140
# lenGc 3139
# lenGc 3137
# lenGc 3136
# lenGc 3135
# lenGc 3132
# lenGc 3131
# lenGc 3124
# lenGc 3123
# lenGc 3121
# lenGc 3120
# lenGc 3119
# lenGc 3118
# lenGc 3117
# lenGc 3116
# lenGc 3115
# lenGc 3114
# lenGc 3113
# lenGc 3112
# lenGc 3111
# lenGc 3110
# lenGc 3109
# lenGc 3108
# lenGc 3107
# lenGc 3106
# lenGc 3105
# lenGc 3104
# lenGc 3103
# lenGc 3102
# lenGc 3101
# lenGc 3100
# lenGc 3099
# lenGc 3098
# lenGc 3038
# lenGc 3037
# lenGc 3036
# lenGc 3035
# lenGc 3034
# lenGc 3033
# lenGc 3032
# lenGc 3030
# lenGc 3029
# lenGc 3027
# lenGc 3026
# lenGc 3022
# lenGc 3021
# lenGc 3020
# lenGc 3019
# lenGc 3018
# lenGc 3017
# lenGc 3016
# lenGc 3015
# lenGc 3014
# lenGc 3013
# lenGc 3012
# lenGc 3011
# lenGc 3010
# lenGc 3009
# lenGc 3008
# lenGc 3007
# lenGc 3006
# lenGc 3005
# lenGc 3003
# lenGc 3002
# lenGc 3001
# lenGc 2999
# lenGc 2998
# lenGc 2997
# lenGc 2996
# lenGc 2995
# lenGc 2993
# lenGc 2992
# lenGc 2991
# lenGc 2990
# lenGc 2989
# lenGc 2988
# lenGc 2987
# lenGc 2986
# lenGc 2985
# lenGc 2984
# lenGc 2983
# lenGc 2982
# lenGc 2981
# lenGc 2980
# lenGc 2979
# lenGc 2978
# lenGc 2977
# lenGc 2976
# lenGc 2975
# lenGc 2974
# lenGc 2973
# lenGc 2971
# lenGc 2970
# lenGc 2969
# lenGc 2968
# lenGc 2967
# lenGc 2966
# lenGc 2961
# lenGc 2960
# lenGc 2959
# lenGc 2958
# lenGc 2957
# lenGc 2956
# lenGc 2955
# lenGc 2954
# lenGc 2951
# lenGc 2950
# lenGc 2949
# lenGc 2948
# lenGc 2947
# lenGc 2946
# lenGc 2945
# lenGc 2942
# lenGc 2941
# lenGc 2940
# lenGc 2939
# lenGc 2938
# lenGc 2937
# lenGc 2936
# lenGc 2935
# lenGc 2934
# lenGc 2933
# lenGc 2932
# lenGc 2930
# lenGc 2929
# lenGc 2928
# lenGc 2927
# lenGc 2926
# lenGc 2925
# lenGc 2924
# lenGc 2923
# lenGc 2922
# lenGc 2921
# lenGc 2920
# lenGc 2919
# lenGc 2918
# lenGc 2917
# lenGc 2911
# lenGc 2910
# lenGc 2903
# lenGc 2902
# lenGc 2901
# lenGc 2900
# lenGc 2899
# lenGc 2898
# lenGc 2897
# lenGc 2896
# lenGc 2895
# lenGc 2894
# lenGc 2892
# lenGc 2891
# lenGc 2890
# lenGc 2889
# lenGc 2888
# lenGc 2886
# lenGc 2885
# lenGc 2884
# lenGc 2883
# lenGc 2881
# lenGc 2880
# lenGc 2879
# lenGc 2878
# lenGc 2877
# lenGc 2876
# lenGc 2875
# lenGc 2874
# lenGc 2873
# lenGc 2872
# lenGc 2871
# lenGc 2870
# lenGc 2869
# lenGc 2867
# lenGc 2866
# lenGc 2865
# lenGc 2864
# lenGc 2863
# lenGc 2862
# lenGc 2860
# lenGc 2859
# lenGc 2858
# lenGc 2857
# lenGc 2856
# lenGc 2855
# lenGc 2854
# lenGc 2852
# lenGc 2851
# lenGc 2847
# lenGc 2846
# lenGc 2845
# lenGc 2844
# lenGc 2843
# lenGc 2842
# lenGc 2841
# lenGc 2840
# lenGc 2839
# lenGc 2838
# lenGc 2837
# lenGc 2836
# lenGc 2835
# lenGc 2830
# lenGc 2829
# lenGc 2828
# lenGc 2827
# lenGc 2826
# lenGc 2825
# lenGc 2823
# lenGc 2822
# lenGc 2821
# lenGc 2820
# lenGc 2819
# lenGc 2818
# lenGc 2817
# lenGc 2816
# lenGc 2815
# lenGc 2814
# lenGc 2801
# lenGc 2800
# lenGc 2799
# lenGc 2798
# lenGc 2797
# lenGc 2795
# lenGc 2794
# lenGc 2793
# lenGc 2792
# lenGc 2791
# lenGc 2790
# lenGc 2789
# lenGc 2788
# lenGc 2787
# lenGc 2786
# lenGc 2785
# lenGc 2783
# lenGc 2782
# lenGc 2781
# lenGc 2780
# lenGc 2779
# lenGc 2778
# lenGc 2777
# lenGc 2776
# lenGc 2775
# lenGc 2774
# lenGc 2773
# lenGc 2772
# lenGc 2770
# lenGc 2767
# lenGc 2766
# lenGc 2765
# lenGc 2764
# lenGc 2763
# lenGc 2762
# lenGc 2761
# lenGc 2760
# lenGc 2759
# lenGc 2758
# lenGc 2757
# lenGc 2755
# lenGc 2754
# lenGc 2753
# lenGc 2752
# lenGc 2751
# lenGc 2750
# lenGc 2749
# lenGc 2748
# lenGc 2747
# lenGc 2746
# lenGc 2745
# lenGc 2742
# lenGc 2741
# lenGc 2740
# lenGc 2739
# lenGc 2738
# lenGc 2729
# lenGc 2728
# lenGc 2727
# lenGc 2725
# lenGc 2724
# lenGc 2723
# lenGc 2722
# lenGc 2721
# lenGc 2716
# lenGc 2715
# lenGc 2714
# lenGc 2713
# lenGc 2712
# lenGc 2710
# lenGc 2709
# lenGc 2703
# lenGc 2702
# lenGc 2701
# lenGc 2700
# lenGc 2699
# lenGc 2698
# lenGc 2697
# lenGc 2696
# lenGc 2695
# lenGc 2694
# lenGc 2693
# lenGc 2687
# lenGc 2686
# lenGc 2685
# lenGc 2684
# lenGc 2683
# lenGc 2682
# lenGc 2678
# lenGc 2677
# lenGc 2675
# lenGc 2674
# lenGc 2673
# lenGc 2671
# lenGc 2670
# lenGc 2669
# lenGc 2668
# lenGc 2667
# lenGc 2666
# lenGc 2665
# lenGc 2664
# lenGc 2662
# lenGc 2661
# lenGc 2660
# lenGc 2659
# lenGc 2658
# lenGc 2655
# lenGc 2654
# lenGc 2653
# lenGc 2652
# lenGc 2651
# lenGc 2650
# lenGc 2649
# lenGc 2648
# lenGc 2647
# lenGc 2646
# lenGc 2645
# lenGc 2644
# lenGc 2643
# lenGc 2642
# lenGc 2641
# lenGc 2640
# lenGc 2639
# lenGc 2638
# lenGc 2637
# lenGc 2636
# lenGc 2634
# lenGc 2633
# lenGc 2631
# lenGc 2630
# lenGc 2628
# lenGc 2627
# lenGc 2626
# lenGc 2625
# lenGc 2624
# lenGc 2621
# lenGc 2620
# lenGc 2619
# lenGc 2618
# lenGc 2617
# lenGc 2616
# lenGc 2615
# lenGc 2614
# lenGc 2613
# lenGc 2612
# lenGc 2611
# lenGc 2610
# lenGc 2609
# lenGc 2608
# lenGc 2606
# lenGc 2605
# lenGc 2604
# lenGc 2603
# lenGc 2602
# lenGc 2601
# lenGc 2600
# lenGc 2599
# lenGc 2598
# lenGc 2597
# lenGc 2596
# lenGc 2573
# lenGc 2572
# lenGc 2571
# lenGc 2570
# lenGc 2569
# lenGc 2563
# lenGc 2562
# lenGc 2561
# lenGc 2560
# lenGc 2557
# lenGc 2556
# lenGc 2555
# lenGc 2554
# lenGc 2553
# lenGc 2551
# lenGc 2550
# lenGc 2549
# lenGc 2548
# lenGc 2547
# lenGc 2546
# lenGc 2544
# lenGc 2543
# lenGc 2542
# lenGc 2541
# lenGc 2540
# lenGc 2538
# lenGc 2537
# lenGc 2536
# lenGc 2535
# lenGc 2534
# lenGc 2533
# lenGc 2532
# lenGc 2531
# lenGc 2530
# lenGc 2529
# lenGc 2528
# lenGc 2526
# lenGc 2525
# lenGc 2522
# lenGc 2521
# lenGc 2519
# lenGc 2517
# lenGc 2516
# lenGc 2515
# lenGc 2514
# lenGc 2513
# lenGc 2510
# lenGc 2509
# lenGc 2508
# lenGc 2507
# lenGc 2506
# lenGc 2505
# lenGc 2504
# lenGc 2503
# lenGc 2501
# lenGc 2500
# lenGc 2498
# lenGc 2495
# lenGc 2494
# lenGc 2493
# lenGc 2492
# lenGc 2491
# lenGc 2490
# lenGc 2489
# lenGc 2488
# lenGc 2487
# lenGc 2486
# lenGc 2485
# lenGc 2484
# lenGc 2483
# lenGc 2482
# lenGc 2481
# lenGc 2480
# lenGc 2479
# lenGc 2478
# lenGc 2477
# lenGc 2476
# lenGc 2475
# lenGc 2474
# lenGc 2473
# lenGc 2472
# lenGc 2471
# lenGc 2469
# lenGc 2467
# lenGc 2466
# lenGc 2465
# lenGc 2464
# lenGc 2463
# lenGc 2462
# lenGc 2461
# lenGc 2460
# lenGc 2459
# lenGc 2458
# lenGc 2457
# lenGc 2456
# lenGc 2455
# lenGc 2454
# lenGc 2453
# lenGc 2452
# lenGc 2451
# lenGc 2450
# lenGc 2449
# lenGc 2448
# lenGc 2447
# lenGc 2446
# lenGc 2445
# lenGc 2444
# lenGc 2443
# lenGc 2442
# lenGc 2441
# lenGc 2440
# lenGc 2439
# lenGc 2438
# lenGc 2437
# lenGc 2436
# lenGc 2435
# lenGc 2434
# lenGc 2432
# lenGc 2431
# lenGc 2430
# lenGc 2429
# lenGc 2428
# lenGc 2427
# lenGc 2426
# lenGc 2425
# lenGc 2424
# lenGc 2423
# lenGc 2412
# lenGc 2411
# lenGc 2410
# lenGc 2409
# lenGc 2408
# lenGc 2407
# lenGc 2406
# lenGc 2405
# lenGc 2404
# lenGc 2403
# lenGc 2402
# lenGc 2401
# lenGc 2400
# lenGc 2399
# lenGc 2398
# lenGc 2397
# lenGc 2396
# lenGc 2395
# lenGc 2394
# lenGc 2393
# lenGc 2392
# lenGc 2391
# lenGc 2389
# lenGc 2388
# lenGc 2387
# lenGc 2386
# lenGc 2385
# lenGc 2384
# lenGc 2383
# lenGc 2380
# lenGc 2379
# lenGc 2378
# lenGc 2377
# lenGc 2376
# lenGc 2375
# lenGc 2374
# lenGc 2372
# lenGc 2371
# lenGc 2370
# lenGc 2369
# lenGc 2368
# lenGc 2367
# lenGc 2366
# lenGc 2365
# lenGc 2364
# lenGc 2363
# lenGc 2362
# lenGc 2361
# lenGc 2360
# lenGc 2359
# lenGc 2358
# lenGc 2357
# lenGc 2356
# lenGc 2355
# lenGc 2354
# lenGc 2353
# lenGc 2350
# lenGc 2349
# lenGc 2348
# lenGc 2347
# lenGc 2346
# lenGc 2345
# lenGc 2344
# lenGc 2343
# lenGc 2342
# lenGc 2341
# lenGc 2340
# lenGc 2338
# lenGc 2334
# lenGc 2333
# lenGc 2331
# lenGc 2330
# lenGc 2329
# lenGc 2328
# lenGc 2327
# lenGc 2326
# lenGc 2325
# lenGc 2324
# lenGc 2322
# lenGc 2321
# lenGc 2320
# lenGc 2319
# lenGc 2315
# lenGc 2314
# lenGc 2313
# lenGc 2312
# lenGc 2311
# lenGc 2310
# lenGc 2309
# lenGc 2308
# lenGc 2306
# lenGc 2304
# lenGc 2303
# lenGc 2302
# lenGc 2301
# lenGc 2300
# lenGc 2299
# lenGc 2297
# lenGc 2296
# lenGc 2295
# lenGc 2294
# lenGc 2293
# lenGc 2292
# lenGc 2291
# lenGc 2290
# lenGc 2289
# lenGc 2287
# lenGc 2286
# lenGc 2285
# lenGc 2284
# lenGc 2283
# lenGc 2282
# lenGc 2281
# lenGc 2280
# lenGc 2279
# lenGc 2278
# lenGc 2277
# lenGc 2276
# lenGc 2275
# lenGc 2274
# lenGc 2273
# lenGc 2272
# lenGc 2270
# lenGc 2269
# lenGc 2268
# lenGc 2267
# lenGc 2266
# lenGc 2265
# lenGc 2264
# lenGc 2263
# lenGc 2262
# lenGc 2261
# lenGc 2260
# lenGc 2259
# lenGc 2258
# lenGc 2257
# lenGc 2253
# lenGc 2252
# lenGc 2251
# lenGc 2250
# lenGc 2205
# lenGc 2204
# lenGc 2203
# lenGc 2202
# lenGc 2201
# lenGc 2200
# lenGc 2199
# lenGc 2198
# lenGc 2197
# lenGc 2196
# lenGc 2195
# lenGc 2194
# lenGc 2193
# lenGc 2192
# lenGc 2190
# lenGc 2189
# lenGc 2182
# lenGc 2181
# lenGc 2180
# lenGc 2178
# lenGc 2177
# lenGc 2176
# lenGc 2175
# lenGc 2174
# lenGc 2173
# lenGc 2172
# lenGc 2171
# lenGc 2170
# lenGc 2169
# lenGc 2168
# lenGc 2167
# lenGc 2166
# lenGc 2165
# lenGc 2164
# lenGc 2163
# lenGc 2162
# lenGc 2161
# lenGc 2160
# lenGc 2159
# lenGc 2158
# lenGc 2157
# lenGc 2156
# lenGc 2155
# lenGc 2154
# lenGc 2153
# lenGc 2152
# lenGc 2151
# lenGc 2150
# lenGc 2149
# lenGc 2148
# lenGc 2147
# lenGc 2145
# lenGc 2144
# lenGc 2143
# lenGc 2142
# lenGc 2136
# lenGc 2135
# lenGc 2134
# lenGc 2133
# lenGc 2132
# lenGc 2131
# lenGc 2129
# lenGc 2126
# lenGc 2125
# lenGc 2124
# lenGc 2123
# lenGc 2121
# lenGc 2120
# lenGc 2119
# lenGc 2117
# lenGc 2116
# lenGc 2115
# lenGc 2114
# lenGc 2113
# lenGc 2112
# lenGc 2110
# lenGc 2102
# lenGc 2101
# lenGc 2100
# lenGc 2099
# lenGc 2098
# lenGc 2097
# lenGc 2096
# lenGc 2095
# lenGc 2094
# lenGc 2093
# lenGc 2092
# lenGc 2091
# lenGc 2090
# lenGc 2089
# lenGc 2088
# lenGc 2086
# lenGc 2085
# lenGc 2084
# lenGc 2083
# lenGc 2082
# lenGc 2080
# lenGc 2079
# lenGc 2078
# lenGc 2077
# lenGc 2075
# lenGc 2074
# lenGc 2073
# lenGc 2072
# lenGc 2071
# lenGc 2070
# lenGc 2069
# lenGc 2068
# lenGc 2067
# lenGc 2066
# lenGc 2065
# lenGc 2064
# lenGc 2063
# lenGc 2061
# lenGc 2060
# lenGc 2059
# lenGc 2058
# lenGc 2057
# lenGc 2056
# lenGc 2055
# lenGc 2052
# lenGc 2049
# lenGc 2048
# lenGc 2047
# lenGc 2046
# lenGc 2045
# lenGc 2042
# lenGc 2040
# lenGc 2038
# lenGc 2037
# lenGc 2035
# lenGc 2034
# lenGc 2033
# lenGc 2032
# lenGc 2031
# lenGc 2030
# lenGc 2029
# lenGc 2028
# lenGc 2025
# lenGc 2024
# lenGc 2023
# lenGc 2021
# lenGc 2020
# lenGc 2019
# lenGc 2018
# lenGc 2017
# lenGc 2016
# lenGc 2015
# lenGc 2014
# lenGc 2013
# lenGc 2010
# lenGc 2009
# lenGc 2008
# lenGc 2007
# lenGc 2003
# lenGc 2002
# lenGc 2001
# lenGc 1998
# lenGc 1997
# lenGc 1996
# lenGc 1995
# lenGc 1994
# lenGc 1993
# lenGc 1992
# lenGc 1991
# lenGc 1990
# lenGc 1989
# lenGc 1988
# lenGc 1987
# lenGc 1986
# lenGc 1985
# lenGc 1984
# lenGc 1982
# lenGc 1981
# lenGc 1979
# lenGc 1976
# lenGc 1975
# lenGc 1974
# lenGc 1970
# lenGc 1969
# lenGc 1968
# lenGc 1967
# lenGc 1966
# lenGc 1965
# lenGc 1964
# lenGc 1962
# lenGc 1961
# lenGc 1960
# lenGc 1959
# lenGc 1958
# lenGc 1957
# lenGc 1956
# lenGc 1955
# lenGc 1954
# lenGc 1953
# lenGc 1950
# lenGc 1949
# lenGc 1948
# lenGc 1947
# lenGc 1942
# lenGc 1941
# lenGc 1940
# lenGc 1939
# lenGc 1938
# lenGc 1935
# lenGc 1934
# lenGc 1931
# lenGc 1930
# lenGc 1929
# lenGc 1928
# lenGc 1927
# lenGc 1926
# lenGc 1925
# lenGc 1924
# lenGc 1923
# lenGc 1922
# lenGc 1921
# lenGc 1920
# lenGc 1919
# lenGc 1918
# lenGc 1917
# lenGc 1916
# lenGc 1915
# lenGc 1914
# lenGc 1912
# lenGc 1911
# lenGc 1907
# lenGc 1906
# lenGc 1905
# lenGc 1904
# lenGc 1903
# lenGc 1898
# lenGc 1897
# lenGc 1896
# lenGc 1895
# lenGc 1894
# lenGc 1893
# lenGc 1892
# lenGc 1890
# lenGc 1889
# lenGc 1888
# lenGc 1887
# lenGc 1886
# lenGc 1885
# lenGc 1883
# lenGc 1882
# lenGc 1881
# lenGc 1880
# lenGc 1879
# lenGc 1878
# lenGc 1877
# lenGc 1876
# lenGc 1875
# lenGc 1873
# lenGc 1872
# lenGc 1871
# lenGc 1869
# lenGc 1868
# lenGc 1867
# lenGc 1866
# lenGc 1865
# lenGc 1864
# lenGc 1863
# lenGc 1862
# lenGc 1861
# lenGc 1860
# lenGc 1859
# lenGc 1858
# lenGc 1856
# lenGc 1854
# lenGc 1851
# lenGc 1850
# lenGc 1849
# lenGc 1848
# lenGc 1847
# lenGc 1846
# lenGc 1845
# lenGc 1844
# lenGc 1843
# lenGc 1842
# lenGc 1841
# lenGc 1839
# lenGc 1838
# lenGc 1837
# lenGc 1836
# lenGc 1835
# lenGc 1834
# lenGc 1833
# lenGc 1832
# lenGc 1831
# lenGc 1830
# lenGc 1829
# lenGc 1827
# lenGc 1826
# lenGc 1825
# lenGc 1823
# lenGc 1822
# lenGc 1821
# lenGc 1820
# lenGc 1815
# lenGc 1811
# lenGc 1810
# lenGc 1809
# lenGc 1808
# lenGc 1804
# lenGc 1803
# lenGc 1801
# lenGc 1800
# lenGc 1799
# lenGc 1798
# lenGc 1797
# lenGc 1796
# lenGc 1795
# lenGc 1794
# lenGc 1793
# lenGc 1792
# lenGc 1791
# lenGc 1789
# lenGc 1787
# lenGc 1786
# lenGc 1785
# lenGc 1784
# lenGc 1783
# lenGc 1782
# lenGc 1781
# lenGc 1779
# lenGc 1778
# lenGc 1777
# lenGc 1775
# lenGc 1774
# lenGc 1773
# lenGc 1772
# lenGc 1771
# lenGc 1770
# lenGc 1766
# lenGc 1765
# lenGc 1764
# lenGc 1763
# lenGc 1762
# lenGc 1761
# lenGc 1760
# lenGc 1756
# lenGc 1755
# lenGc 1754
# lenGc 1753
# lenGc 1752
# lenGc 1751
# lenGc 1749
# lenGc 1748
# lenGc 1747
# lenGc 1745
# lenGc 1744
# lenGc 1743
# lenGc 1741
# lenGc 1740
# lenGc 1739
# lenGc 1738
# lenGc 1737
# lenGc 1735
# lenGc 1727
# lenGc 1726
# lenGc 1725
# lenGc 1724
# lenGc 1723
# lenGc 1722
# lenGc 1720
# lenGc 1719
# lenGc 1718
# lenGc 1717
# lenGc 1715
# lenGc 1714
# lenGc 1713
# lenGc 1712
# lenGc 1711
# lenGc 1710
# lenGc 1709
# lenGc 1708
# lenGc 1707
# lenGc 1704
# lenGc 1701
# lenGc 1700
# lenGc 1689
# lenGc 1688
# lenGc 1687
# lenGc 1686
# lenGc 1685
# lenGc 1682
# lenGc 1681
# lenGc 1680
# lenGc 1679
# lenGc 1678
# lenGc 1677
# lenGc 1676
# lenGc 1673
# lenGc 1672
# lenGc 1671
# lenGc 1668
# lenGc 1667
# lenGc 1666
# lenGc 1662
# lenGc 1661
# lenGc 1660
# lenGc 1659
# lenGc 1658
# lenGc 1657
# lenGc 1656
# lenGc 1653
# lenGc 1652
# lenGc 1649
# lenGc 1646
# lenGc 1645
# lenGc 1644
# lenGc 1643
# lenGc 1642
# lenGc 1641
# lenGc 1640
# lenGc 1639
# lenGc 1638
# lenGc 1637
# lenGc 1636
# lenGc 1635
# lenGc 1634
# lenGc 1633
# lenGc 1632
# lenGc 1631
# lenGc 1630
# lenGc 1629
# lenGc 1628
# lenGc 1627
# lenGc 1624
# lenGc 1623
# lenGc 1622
# lenGc 1621
# lenGc 1618
# lenGc 1617
# lenGc 1616
# lenGc 1614
# lenGc 1613
# lenGc 1611
# lenGc 1610
# lenGc 1609
# lenGc 1608
# lenGc 1600
# lenGc 1599
# lenGc 1598
# lenGc 1597
# lenGc 1596
# lenGc 1595
# lenGc 1593
# lenGc 1592
# lenGc 1591
# lenGc 1590
# lenGc 1586
# lenGc 1585
# lenGc 1584
# lenGc 1583
# lenGc 1582
# lenGc 1581
# lenGc 1580
# lenGc 1579
# lenGc 1578
# lenGc 1577
# lenGc 1576
# lenGc 1575
# lenGc 1574
# lenGc 1573
# lenGc 1572
# lenGc 1571
# lenGc 1570
# lenGc 1569
# lenGc 1568
# lenGc 1567
# lenGc 1566
# lenGc 1556
# lenGc 1555
# lenGc 1554
# lenGc 1553
# lenGc 1552
# lenGc 1550
# lenGc 1549
# lenGc 1548
# lenGc 1547
# lenGc 1541
# lenGc 1539
# lenGc 1538
# lenGc 1537
# lenGc 1536
# lenGc 1535
# lenGc 1530
# lenGc 1529
# lenGc 1527
# lenGc 1526
# lenGc 1525
# lenGc 1524
# lenGc 1523
# lenGc 1522
# lenGc 1520
# lenGc 1519
# lenGc 1517
# lenGc 1515
# lenGc 1514
# lenGc 1513
# lenGc 1512
# lenGc 1511
# lenGc 1510
# lenGc 1509
# lenGc 1508
# lenGc 1507
# lenGc 1506
# lenGc 1505
# lenGc 1504
# lenGc 1503
# lenGc 1502
# lenGc 1501
# lenGc 1499
# lenGc 1498
# lenGc 1497
# lenGc 1495
# lenGc 1494
# lenGc 1493
# lenGc 1492
# lenGc 1491
# lenGc 1490
# lenGc 1489
# lenGc 1488
# lenGc 1487
# lenGc 1486
# lenGc 1485
# lenGc 1484
# lenGc 1483
# lenGc 1481
# lenGc 1480
# lenGc 1479
# lenGc 1478
# lenGc 1477
# lenGc 1476
# lenGc 1475
# lenGc 1474
# lenGc 1473
# lenGc 1471
# lenGc 1470
# lenGc 1464
# lenGc 1463
# lenGc 1462
# lenGc 1461
# lenGc 1457
# lenGc 1456
# lenGc 1455
# lenGc 1454
# lenGc 1453
# lenGc 1452
# lenGc 1451
# lenGc 1450
# lenGc 1449
# lenGc 1448
# lenGc 1447
# lenGc 1445
# lenGc 1444
# lenGc 1443
# lenGc 1442
# lenGc 1441
# lenGc 1440
# lenGc 1439
# lenGc 1438
# lenGc 1437
# lenGc 1436
# lenGc 1435
# lenGc 1434
# lenGc 1433
# lenGc 1431
# lenGc 1430
# lenGc 1429
# lenGc 1428
# lenGc 1427
# lenGc 1426
# lenGc 1410
# lenGc 1408
# lenGc 1407
# lenGc 1403
# lenGc 1402
# lenGc 1401
# lenGc 1400
# lenGc 1399
# lenGc 1398
# lenGc 1397
# lenGc 1396
# lenGc 1395
# lenGc 1394
# lenGc 1393
# lenGc 1392
# lenGc 1391
# lenGc 1390
# lenGc 1389
# lenGc 1388
# lenGc 1386
# lenGc 1385
# lenGc 1384
# lenGc 1383
# lenGc 1382
# lenGc 1381
# lenGc 1380
# lenGc 1379
# lenGc 1377
# lenGc 1376
# lenGc 1375
# lenGc 1374
# lenGc 1372
# lenGc 1371
# lenGc 1369
# lenGc 1358
# lenGc 1357
# lenGc 1356
# lenGc 1352
# lenGc 1351
# lenGc 1350
# lenGc 1349
# lenGc 1348
# lenGc 1347
# lenGc 1346
# lenGc 1345
# lenGc 1344
# lenGc 1339
# lenGc 1337
# lenGc 1336
# lenGc 1335
# lenGc 1334
# lenGc 1333
# lenGc 1332
# lenGc 1331
# lenGc 1330
# lenGc 1329
# lenGc 1324
# lenGc 1323
# lenGc 1320
# lenGc 1319
# lenGc 1311
# lenGc 1310
# lenGc 1309
# lenGc 1308
# lenGc 1307
# lenGc 1306
# lenGc 1305
# lenGc 1304
# lenGc 1303
# lenGc 1302
# lenGc 1301
# lenGc 1300
# lenGc 1299
# lenGc 1295
# lenGc 1291
# lenGc 1290
# lenGc 1289
# lenGc 1288
# lenGc 1287
# lenGc 1284
# lenGc 1282
# lenGc 1281
# lenGc 1280
# lenGc 1279
# lenGc 1272
# lenGc 1270
# lenGc 1268
# lenGc 1267
# lenGc 1266
# lenGc 1265
# lenGc 1264
# lenGc 1263
# lenGc 1262
# lenGc 1261
# lenGc 1260
# lenGc 1259
# lenGc 1258
# lenGc 1257
# lenGc 1256
# lenGc 1255
# lenGc 1254
# lenGc 1253
# lenGc 1252
# lenGc 1251
# lenGc 1250
# lenGc 1244
# lenGc 1243
# lenGc 1242
# lenGc 1240
# lenGc 1239
# lenGc 1237
# lenGc 1236
# lenGc 1235
# lenGc 1234
# lenGc 1233
# lenGc 1232
# lenGc 1231
# lenGc 1230
# lenGc 1229
# lenGc 1228
# lenGc 1226
# lenGc 1225
# lenGc 1224
# lenGc 1223
# lenGc 1221
# lenGc 1219
# lenGc 1218
# lenGc 1215
# lenGc 1212
# lenGc 1211
# lenGc 1210
# lenGc 1206
# lenGc 1205
# lenGc 1204
# lenGc 1203
# lenGc 1201
# lenGc 1200
# lenGc 1199
# lenGc 1195
# lenGc 1191
# lenGc 1190
# lenGc 1189
# lenGc 1188
# lenGc 1185
# lenGc 1179
# lenGc 1178
# lenGc 1177
# lenGc 1176
# lenGc 1175
# lenGc 1174
# lenGc 1173
# lenGc 1172
# lenGc 1171
# lenGc 1169
# lenGc 1168
# lenGc 1167
# lenGc 1166
# lenGc 1164
# lenGc 1162
# lenGc 1161
# lenGc 1159
# lenGc 1158
# lenGc 1157
# lenGc 1156
# lenGc 1155
# lenGc 1153
# lenGc 1151
# lenGc 1150
# lenGc 1149
# lenGc 1148
# lenGc 1147
# lenGc 1146
# lenGc 1145
# lenGc 1144
# lenGc 1141
# lenGc 1139
# lenGc 1133
# lenGc 1132
# lenGc 1131
# lenGc 1130
# lenGc 1129
# lenGc 1128
# lenGc 1127
# lenGc 1126
# lenGc 1125
# lenGc 1124
# lenGc 1122
# lenGc 1121
# lenGc 1120
# lenGc 1119
# lenGc 1118
# lenGc 1110
# lenGc 1108
# lenGc 1106
# lenGc 1105
# lenGc 1104
# lenGc 1103
# lenGc 1102
# lenGc 1100
# lenGc 1099
# lenGc 1098
# lenGc 1096
# lenGc 1095
# lenGc 1094
# lenGc 1093
# lenGc 1092
# lenGc 1091
# lenGc 1090
# lenGc 1089
# lenGc 1088
# lenGc 1087
# lenGc 1086
# lenGc 1085
# lenGc 1084
# lenGc 1083
# lenGc 1082
# lenGc 1081
# lenGc 1078
# lenGc 1077
# lenGc 1076
# lenGc 1074
# lenGc 1073
# lenGc 1072
# lenGc 1071
# lenGc 1070
# lenGc 1069
# lenGc 1064
# lenGc 1063
# lenGc 1062
# lenGc 1056
# lenGc 1049
# lenGc 1047
# lenGc 1046
# lenGc 1045
# lenGc 1044
# lenGc 1043
# lenGc 1042
# lenGc 1041
# lenGc 1040
# lenGc 1039
# lenGc 1038
# lenGc 1037
# lenGc 1036
# lenGc 1035
# lenGc 1034
# lenGc 1023
# lenGc 1022
# lenGc 1018
# lenGc 1017
# lenGc 1016
# lenGc 1015
# lenGc 1014
# lenGc 1012
# lenGc 1011
# lenGc 1010
# lenGc 1006
# lenGc 1005
# lenGc 1003
# lenGc 1002
# lenGc 1001
# lenGc 1000
# lenGc 999
# lenGc 998
# lenGc 997
# lenGc 996
# lenGc 994
# lenGc 993
# lenGc 992
# lenGc 990
# lenGc 989
# lenGc 988
# lenGc 986
# lenGc 985
# lenGc 984
# lenGc 982
# lenGc 981
# lenGc 980
# lenGc 973
# lenGc 972
# lenGc 971
# lenGc 970
# lenGc 969
# lenGc 968
# lenGc 967
# lenGc 966
# lenGc 965
# lenGc 961
# lenGc 960
# lenGc 959
# lenGc 958
# lenGc 956
# lenGc 955
# lenGc 954
# lenGc 952
# lenGc 951
# lenGc 950
# lenGc 948
# lenGc 947
# lenGc 946
# lenGc 945
# lenGc 944
# lenGc 943
# lenGc 942
# lenGc 941
# lenGc 940
# lenGc 939
# lenGc 937
# lenGc 936
# lenGc 935
# lenGc 934
# lenGc 931
# lenGc 930
# lenGc 929
# lenGc 928
# lenGc 927
# lenGc 926
# lenGc 925
# lenGc 924
# lenGc 923
# lenGc 922
# lenGc 921
# lenGc 920
# lenGc 919
# lenGc 918
# lenGc 917
# lenGc 916
# lenGc 915
# lenGc 914
# lenGc 913
# lenGc 912
# lenGc 911
# lenGc 910
# lenGc 909
# lenGc 908
# lenGc 907
# lenGc 906
# lenGc 905
# lenGc 904
# lenGc 903
# lenGc 902
# lenGc 901
# lenGc 900
# lenGc 899
# lenGc 898
# lenGc 897
# lenGc 896
# lenGc 890
# lenGc 889
# lenGc 887
# lenGc 886
# lenGc 885
# lenGc 883
# lenGc 882
# lenGc 881
# lenGc 880
# lenGc 879
# lenGc 878
# lenGc 877
# lenGc 876
# lenGc 875
# lenGc 874
# lenGc 873
# lenGc 872
# lenGc 871
# lenGc 864
# lenGc 863
# lenGc 859
# lenGc 858
# lenGc 857
# lenGc 854
# lenGc 853
# lenGc 852
# lenGc 851
# lenGc 850
# lenGc 849
# lenGc 847
# lenGc 846
# lenGc 845
# lenGc 841
# lenGc 839
# lenGc 838
# lenGc 836
# lenGc 835
# lenGc 834
# lenGc 833
# lenGc 832
# lenGc 831
# lenGc 830
# lenGc 829
# lenGc 828
# lenGc 826
# lenGc 825
# lenGc 824
# lenGc 823
# lenGc 822
# lenGc 813
# lenGc 812
# lenGc 811
# lenGc 810
# lenGc 809
# lenGc 808
# lenGc 807
# lenGc 803
# lenGc 802
# lenGc 799
# lenGc 798
# lenGc 797
# lenGc 796
# lenGc 795
# lenGc 794
# lenGc 793
# lenGc 791
# lenGc 790
# lenGc 789
# lenGc 787
# lenGc 786
# lenGc 783
# lenGc 782
# lenGc 779
# lenGc 777
# lenGc 775
# lenGc 774
# lenGc 770
# lenGc 766
# lenGc 764
# lenGc 763
# lenGc 762
# lenGc 760
# lenGc 759
# lenGc 758
# lenGc 757
# lenGc 756
# lenGc 753
# lenGc 752
# lenGc 751
# lenGc 749
# lenGc 748
# lenGc 747
# lenGc 746
# lenGc 745
# lenGc 744
# lenGc 743
# lenGc 742
# lenGc 741
# lenGc 740
# lenGc 739
# lenGc 737
# lenGc 736
# lenGc 735
# lenGc 727
# lenGc 726
# lenGc 725
# lenGc 724
# lenGc 723
# lenGc 722
# lenGc 721
# lenGc 715
# lenGc 714
# lenGc 713
# lenGc 712
# lenGc 690
# lenGc 688
# lenGc 683
# lenGc 681
# lenGc 680
# lenGc 679
# lenGc 678
# lenGc 677
# lenGc 676
# lenGc 675
# lenGc 674
# lenGc 673
# lenGc 672
# lenGc 671
# lenGc 668
# lenGc 666
# lenGc 664
# lenGc 662
# lenGc 659
# lenGc 658
# lenGc 657
# lenGc 656
# lenGc 655
# lenGc 654
# lenGc 653
# lenGc 652
# lenGc 651
# lenGc 650
# lenGc 648
# lenGc 647
# lenGc 646
# lenGc 643
# lenGc 642
# lenGc 641
# lenGc 639
# lenGc 638
# lenGc 637
# lenGc 636
# lenGc 635
# lenGc 634
# lenGc 633
# lenGc 632
# lenGc 631
# lenGc 630
# lenGc 629
# lenGc 626
# lenGc 625
# lenGc 624
# lenGc 623
# lenGc 621
# lenGc 620
# lenGc 619
# lenGc 618
# lenGc 617
# lenGc 616
# lenGc 615
# lenGc 614
# lenGc 613
# lenGc 611
# lenGc 610
# lenGc 608
# lenGc 607
# lenGc 606
# lenGc 604
# lenGc 603
# lenGc 602
# lenGc 601
# lenGc 600
# lenGc 599
# lenGc 598
# lenGc 597
# lenGc 596
# lenGc 595
# lenGc 594
# lenGc 593
# lenGc 592
# lenGc 586
# lenGc 585
# lenGc 584
# lenGc 573
# lenGc 571
# lenGc 570
# lenGc 568
# lenGc 565
# lenGc 564
# lenGc 563
# lenGc 562
# lenGc 561
# lenGc 560
# lenGc 559
# lenGc 558
# lenGc 556
# lenGc 555
# lenGc 554
# lenGc 553
# lenGc 552
# lenGc 551
# lenGc 550
# lenGc 549
# lenGc 548
# lenGc 545
# lenGc 544
# lenGc 543
# lenGc 542
# lenGc 541
# lenGc 540
# lenGc 539
# lenGc 538
# lenGc 537
# lenGc 536
# lenGc 535
# lenGc 533
# lenGc 532
# lenGc 531
# lenGc 530
# lenGc 529
# lenGc 528
# lenGc 527
# lenGc 526
# lenGc 523
# lenGc 522
# lenGc 521
# lenGc 520
# lenGc 518
# lenGc 517
# lenGc 516
# lenGc 514
# lenGc 513
# lenGc 509
# lenGc 507
# lenGc 505
# lenGc 504
# lenGc 500
# lenGc 499
# lenGc 498
# lenGc 497
# lenGc 496
# lenGc 495
# lenGc 492
# lenGc 491
# lenGc 490
# lenGc 489
# lenGc 481
# lenGc 480
# lenGc 479
# lenGc 478
# lenGc 476
# lenGc 475
# lenGc 474
# lenGc 473
# lenGc 472
# lenGc 471
# lenGc 469
# lenGc 468
# lenGc 466
# lenGc 465
# lenGc 463
# lenGc 462
# lenGc 461
# lenGc 460
# lenGc 457
# lenGc 456
# lenGc 455
# lenGc 454
# lenGc 453
# lenGc 452
# lenGc 451
# lenGc 445
# lenGc 444
# lenGc 440
# lenGc 436
# lenGc 435
# lenGc 434
# lenGc 432
# lenGc 429
# lenGc 428
# lenGc 427
# lenGc 426
# lenGc 425
# lenGc 421
# lenGc 420
# lenGc 419
# lenGc 418
# lenGc 417
# lenGc 416
# lenGc 415
# lenGc 414
# lenGc 412
# lenGc 411
# lenGc 410
# lenGc 408
# lenGc 407
# lenGc 406
# lenGc 405
# lenGc 404
# lenGc 402
# lenGc 401
# lenGc 400
# lenGc 398
# lenGc 397
# lenGc 396
# lenGc 395
# lenGc 394
# lenGc 393
# lenGc 383
# lenGc 382
# lenGc 380
# lenGc 379
# lenGc 378
# lenGc 377
# lenGc 376
# lenGc 371
# lenGc 370
# lenGc 369
# lenGc 368
# lenGc 366
# lenGc 365
# lenGc 361
# lenGc 360
# lenGc 358
# lenGc 357
# lenGc 356
# lenGc 355
# lenGc 354
# lenGc 353
# lenGc 352
# lenGc 351
# lenGc 350
# lenGc 348
# lenGc 347
# lenGc 346
# lenGc 329
# lenGc 328
# lenGc 327
# lenGc 326
# lenGc 325
# lenGc 324
# lenGc 322
# lenGc 318
# lenGc 316
# lenGc 315
# lenGc 314
# lenGc 313
# lenGc 312
# lenGc 311
# lenGc 308
# lenGc 307
# lenGc 305
# lenGc 303
# lenGc 302
# lenGc 301
# lenGc 299
# lenGc 298
# lenGc 294
# lenGc 293
# lenGc 292
# lenGc 291
# lenGc 290
# lenGc 289
# lenGc 288
# lenGc 287
# lenGc 286
# lenGc 285
# lenGc 284
# lenGc 283
# lenGc 282
# lenGc 281
# lenGc 279
# lenGc 278
# lenGc 273
# lenGc 272
# lenGc 271
# lenGc 270
# lenGc 269
# lenGc 267
# lenGc 266
# lenGc 265
# lenGc 263
# lenGc 262
# lenGc 261
# lenGc 252
# lenGc 251
# lenGc 248
# lenGc 246
# lenGc 245
# lenGc 244
# lenGc 243
# lenGc 242
# lenGc 238
# lenGc 237
# lenGc 236
# lenGc 235
# lenGc 234
# lenGc 233
# lenGc 232
# lenGc 231
# lenGc 230
# lenGc 229
# lenGc 228
# lenGc 227
# lenGc 226
# lenGc 225
# lenGc 224
# lenGc 222
# lenGc 221
# lenGc 220
# lenGc 219
# lenGc 218
# lenGc 216
# lenGc 215
# lenGc 214
# lenGc 213
# lenGc 212
# lenGc 209
# lenGc 207
# lenGc 206
# lenGc 205
# lenGc 204
# lenGc 203
# lenGc 202
# lenGc 201
# lenGc 197
# lenGc 196
# lenGc 195
# lenGc 193
# lenGc 192
# lenGc 191
# lenGc 190
# lenGc 189
# lenGc 187
# lenGc 186
# lenGc 185
# lenGc 184
# lenGc 182
# lenGc 181
# lenGc 180
# lenGc 179
# lenGc 178
# lenGc 177
# lenGc 176
# lenGc 171
# lenGc 170
# lenGc 169
# lenGc 168
# lenGc 167
# lenGc 166
# lenGc 165
# lenGc 164
# lenGc 163
# lenGc 162
# lenGc 133
# lenGc 132
# lenGc 131
# lenGc 130
# lenGc 122
# lenGc 121
# lenGc 119
# lenGc 118
# lenGc 116
# lenGc 115
# lenGc 109
# lenGc 106
# lenGc 105
# lenGc 104
# lenGc 103
# lenGc 102
# lenGc 100
# lenGc 99
# lenGc 98
# lenGc 97
# lenGc 95
# lenGc 94
# lenGc 93
# lenGc 92
# lenGc 78
# lenGc 77
# lenGc 76
# lenGc 75
# lenGc 74
# lenGc 73
# lenGc 72
# lenGc 71
# lenGc 66
# lenGc 65
# lenGc 64
# lenGc 63
# lenGc 62
# lenGc 61
# lenGc 60
# lenGc 59
# lenGc 57
# lenGc 56
# lenGc 55
# lenGc 54
# lenGc 53
# lenGc 52
# lenGc 49
# lenGc 48
# lenGc 47
# lenGc 45
# lenGc 44
# lenGc 43
# lenGc 42
# lenGc 41
# lenGc 40
# lenGc 39
# lenGc 36
# lenGc 35
# lenGc 34
# lenGc 32
# lenGc 31
# lenGc 30
# lenGc 29
# lenGc 28
# lenGc 26
# lenGc 25
# lenGc 23
# lenGc 22
# lenGc 21
# lenGc 20
# lenGc 18
# lenGc 17
# lenGc 16
# lenGc 15
# lenGc 12
# lenGc 10
# lenGc 9

# %%
len(FN_R_Y2H),len(LGC_R_Y2H)
# Out:
# (749, 749)

# %% [markdown]
# # VULNERABILIDAD

# %%
plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1) 
plt.title('Red AP-MS')
plt.plot(DegreeAPMS[:,0],DegreeAPMS[:,1],label='degree')
plt.plot(EigenAPMS[:,0],EigenAPMS[:,1],label='eigenvectors')
plt.plot(SubgraphAPMS[:,0],SubgraphAPMS[:,1],label='subgraph')
plt.plot(FN_R_APMS,LGC_R_APMS,label='random')
plt.plot(FN_E_APMS,LGC_E_APMS,'o',label='essentials')
plt.xlabel('Fracción de nodos')
plt.ylabel('Tamaño componente gigante')
plt.legend()

plt.subplot(2, 2, 2) 
plt.title('Red Y2H')
plt.plot(DegreeY2H[:,0],DegreeY2H[:,1],label='degree')
plt.plot(EigenY2H[:,0],EigenY2H[:,1],label='eigenvectors')
plt.plot(SubgraphY2H[:,0],SubgraphY2H[:,1],label='subgraph')
plt.plot(FN_R_Y2H,LGC_R_Y2H,label='random')
plt.plot(FN_E_Y2H,LGC_E_Y2H,'o',label='essentials')
plt.xlabel('Fracción de nodos')
plt.ylabel('Tamaño componente gigante')
plt.legend()

plt.subplot(2, 2, 3) 
plt.title('Red Literatura')
plt.plot(DegreeLIT[:,0],DegreeLIT[:,1],label='degree')
plt.plot(EigenLIT[:,0],EigenLIT[:,1],label='eigenvectors')
plt.plot(SubgraphLIT[:,0],SubgraphLIT[:,1],label='subgraph')
plt.plot(FN_R_LIT,LGC_R_LIT,label='random')
plt.plot(FN_E_LIT,LGC_E_LIT,'o',label='essentials')
plt.xlabel('Fracción de nodos')
plt.ylabel('Tamaño componente gigante')
plt.legend()

plt.subplot(2, 2, 4) 
plt.title('Red Literatura Reguly')
plt.plot(DegreeLIT_R[:,0],DegreeLIT_R[:,1],label='degree')
plt.plot(EigenLIT_R[:,0],EigenLIT_R[:,1],label='eigenvectors')
plt.plot(SubgraphLIT_R[:,0],SubgraphLIT_R[:,1],label='subgraph')
plt.plot(FN_R_LIT_R,LGC_R_LIT_r,label='random')
plt.plot(FN_E_LIT_R,LGC_E_LIT_R,'o',label='essentials')
plt.xlabel('Fracción de nodos')
plt.ylabel('Tamaño componente gigante')
plt.legend()

# %%
# Out:
# 1622
