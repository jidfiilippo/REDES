# %%
import numpy as np
import networkx as nx
import os
from random import shuffle          # importamos las librerias necesarias
import matplotlib.pylab as plt       
# %matplotlib inline
from matplotlib.pyplot import title,xlabel,ylabel,show

# %%
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

# %%
LITREG = ldata('yeast_LIT_Reguly.txt')
#se que cada LITREG[i] es una fila y los dos primeros elementos nos dice un enlace. 
LITREG
# Out:
# [['Bait',
#   'gene/protein',
#   'Hit',
#   'gene/protein',
#   'Bait',
#   'Standard',
#   'Name',
#   'Hit',
#   'Standard',
#   'Name',
#   'Experimental',
#   'System',
#   'Source',
#   'PubMed',
#   'ID'],
#  ['YBR236C',
#   'YML010W',
#   'ABD1',
#   'SPT5',
#   'Affinity',
#   'Capture-MS',
#   'Lindstrom',
#   'DL',
#   'et',
#   'al',
#   '12556496'],
#  ['YML010W',
#   'YBR236C',
#   'SPT5',
#   'ABD1',
#   'Affinity',
#   'Capture-MS',
#   'Lindstrom',
#   'DL',
#   'et',
#   'al',
#   '12556496'],
#  ['YDR448W',
#   'YPL254W',
#   'ADA2',
#   'HFI1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YDR176W',
#   'ADA2',
#   'NGG1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YOR257W',
#   'ADA2',
#   'CDC31',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YGR252W',
#   'ADA2',
#   'GCN5',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YBR010W',
#   'ADA2',
#   'HHT1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YDR225W',
#   'ADA2',
#   'HTA1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YDR159W',
#   'ADA2',
#   'SAC3',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YCL010C',
#   'ADA2',
#   'SGF29',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YGL066W',
#   'ADA2',
#   'SGF73',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YOL148C',
#   'ADA2',
#   'SPT20',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YDR392W',
#   'ADA2',
#   'SPT3',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YBR081C',
#   'ADA2',
#   'SPT7',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YLR055C',
#   'ADA2',
#   'SPT8',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YBR111W-A',
#   'ADA2',
#   'SUS1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YBR111W-A',
#   'YDR448W',
#   'SUS1',
#   'ADA2',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YDR167W',
#   'ADA2',
#   'TAF10',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YDR145W',
#   'ADA2',
#   'TAF12',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YBR198C',
#   'ADA2',
#   'TAF5',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YGL112C',
#   'ADA2',
#   'TAF6',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YMR236W',
#   'ADA2',
#   'TAF9',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YOL072W',
#   'ADA2',
#   'THP1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YHR099W',
#   'ADA2',
#   'TRA1',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YDR448W',
#   'YMR223W',
#   'ADA2',
#   'UBP8',
#   'Affinity',
#   'Capture-MS',
#   'Rodriguez-Navarro',
#   'S',
#   'et',
#   'al',
#   '14718168'],
#  ['YNL172W',
#   'YIR025W',
#   'APC1',
#   'MND2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YIR025W',
#   'YNL172W',
#   'MND2',
#   'APC1',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YLR127C',
#   'YIR025W',
#   'APC2',
#   'MND2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YIR025W',
#   'YLR127C',
#   'MND2',
#   'APC2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YOR249C',
#   'YIR025W',
#   'APC5',
#   'MND2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YIR025W',
#   'YOR249C',
#   'MND2',
#   'APC5',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YDR101C',
#   'YGL099W',
#   'ARX1',
#   'LSG1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YGL099W',
#   'YDR101C',
#   'LSG1',
#   'ARX1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YHR170W',
#   'ARX1',
#   'NMD3',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YPL093W',
#   'ARX1',
#   'NOG1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YGR103W',
#   'ARX1',
#   'NOP7',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YHR052W',
#   'ARX1',
#   'CIC1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YHR052W',
#   'YDR101C',
#   'CIC1',
#   'ARX1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YER006W',
#   'ARX1',
#   'NUG1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YER006W',
#   'YDR101C',
#   'NUG1',
#   'ARX1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YMR308C',
#   'ARX1',
#   'PSE1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YHR197W',
#   'ARX1',
#   'RIX1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YHR197W',
#   'YDR101C',
#   'RIX1',
#   'ARX1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YGR245C',
#   'ARX1',
#   'SDA1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YGR245C',
#   'YDR101C',
#   'SDA1',
#   'ARX1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YBR267W',
#   'ARX1',
#   'REI1',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YCR072C',
#   'ARX1',
#   'YCR072C',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YDR101C',
#   'YPL146C',
#   'ARX1',
#   'RRP16',
#   'Affinity',
#   'Capture-MS',
#   'Nissan',
#   'TA',
#   'et',
#   'al',
#   '12374754'],
#  ['YKL052C',
#   'YDR201W',
#   'ASK1',
#   'SPC19',
#   'Affinity',
#   'Capture-MS',
#   'Janke',
#   'C',
#   'et',
#   'al',
#   '11782438'],
#  ['YOR078W',
#   'YPL217C',
#   'BUD21',
#   'BMS1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YMR128W',
#   'BUD21',
#   'ECM16',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YBR247C',
#   'BUD21',
#   'ENP1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YHR148W',
#   'BUD21',
#   'IMP3',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YER082C',
#   'BUD21',
#   'UTP7',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YNL132W',
#   'BUD21',
#   'KRE33',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YCL059C',
#   'BUD21',
#   'KRR1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YJR002W',
#   'BUD21',
#   'MPP10',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YPL126W',
#   'BUD21',
#   'NAN1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YDL148C',
#   'BUD21',
#   'NOP14',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YLR197W',
#   'BUD21',
#   'SIK1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YDR012W',
#   'BUD21',
#   'RPL4B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YPL198W',
#   'BUD21',
#   'RPL7B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YBL072C',
#   'BUD21',
#   'RPS8A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YER102W',
#   'BUD21',
#   'RPS8B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YPL012W',
#   'BUD21',
#   'RRP12',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YMR229C',
#   'BUD21',
#   'RRP5',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YPR137W',
#   'BUD21',
#   'RRP9',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YGL011C',
#   'BUD21',
#   'SCL1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YBL004W',
#   'BUD21',
#   'UTP20',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YDR324C',
#   'BUD21',
#   'UTP4',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YGR090W',
#   'BUD21',
#   'UTP22',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YGR128C',
#   'BUD21',
#   'UTP8',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YJL109C',
#   'BUD21',
#   'UTP10',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YLR222C',
#   'BUD21',
#   'UTP13',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YMR093W',
#   'BUD21',
#   'UTP15',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR078W',
#   'YJR002W',
#   'BUD21',
#   'MPP10',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YNR052C',
#   'YGR134W',
#   'POP2',
#   'CAF130',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNR052C',
#   'YNL288W',
#   'POP2',
#   'CAF40',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YNR052C',
#   'CAF40',
#   'POP2',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YGR134W',
#   'CAF40',
#   'CAF130',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YAL021C',
#   'CAF40',
#   'CCR4',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YNL288W',
#   'CCR4',
#   'CAF40',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YCR093W',
#   'CAF40',
#   'CDC39',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YCR093W',
#   'YNL288W',
#   'CDC39',
#   'CAF40',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YDL165W',
#   'CAF40',
#   'CDC36',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YIL038C',
#   'CAF40',
#   'NOT3',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YER068W',
#   'CAF40',
#   'MOT2',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YNL288W',
#   'YPR072W',
#   'CAF40',
#   'NOT5',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YNR052C',
#   'CCR4',
#   'POP2',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YNL278W',
#   'CCR4',
#   'CAF120',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YGR134W',
#   'CCR4',
#   'CAF130',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YCR093W',
#   'CCR4',
#   'CDC39',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YCR093W',
#   'YAL021C',
#   'CDC39',
#   'CCR4',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YDL165W',
#   'CCR4',
#   'CDC36',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YER068W',
#   'CCR4',
#   'MOT2',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YAL021C',
#   'YPR072W',
#   'CCR4',
#   'NOT5',
#   'Affinity',
#   'Capture-MS',
#   'Chen',
#   'J',
#   'et',
#   'al',
#   '11733989'],
#  ['YKL022C',
#   'YNL172W',
#   'CDC16',
#   'APC1',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YDL008W',
#   'CDC16',
#   'APC11',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YLR127C',
#   'CDC16',
#   'APC2',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YDR118W',
#   'CDC16',
#   'APC4',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YOR249C',
#   'CDC16',
#   'APC5',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YLR102C',
#   'CDC16',
#   'APC9',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YFR036W',
#   'CDC16',
#   'CDC26',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YBL084C',
#   'CDC16',
#   'CDC27',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YGL240W',
#   'CDC16',
#   'DOC1',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YDR260C',
#   'CDC16',
#   'SWM1',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YDR260C',
#   'YKL022C',
#   'SWM1',
#   'CDC16',
#   'Affinity',
#   'Capture-MS',
#   'Passmore',
#   'LA',
#   'et',
#   'al',
#   '12574115'],
#  ['YKL022C',
#   'YNL172W',
#   'CDC16',
#   'APC1',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YDL008W',
#   'CDC16',
#   'APC11',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YLR127C',
#   'CDC16',
#   'APC2',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YDR118W',
#   'CDC16',
#   'APC4',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YOR249C',
#   'CDC16',
#   'APC5',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YLR102C',
#   'CDC16',
#   'APC9',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YHR166C',
#   'CDC16',
#   'CDC23',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YFR036W',
#   'CDC16',
#   'CDC26',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YBL084C',
#   'CDC16',
#   'CDC27',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YKL022C',
#   'YGL240W',
#   'CDC16',
#   'DOC1',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YGL240W',
#   'YKL022C',
#   'DOC1',
#   'CDC16',
#   'Affinity',
#   'Capture-MS',
#   'Grossberger',
#   'R',
#   'et',
#   'al',
#   '10318877'],
#  ['YHR166C',
#   'YIR025W',
#   'CDC23',
#   'MND2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YIR025W',
#   'YHR166C',
#   'MND2',
#   'CDC23',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YNL172W',
#   'CDC27',
#   'APC1',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YGL240W',
#   'CDC27',
#   'DOC1',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YDL008W',
#   'CDC27',
#   'APC11',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YLR127C',
#   'CDC27',
#   'APC2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YDR118W',
#   'CDC27',
#   'APC4',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YOR249C',
#   'CDC27',
#   'APC5',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YLR102C',
#   'CDC27',
#   'APC9',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YKL022C',
#   'CDC27',
#   'CDC16',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YHR166C',
#   'CDC27',
#   'CDC23',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YFR036W',
#   'CDC27',
#   'CDC26',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YIR025W',
#   'CDC27',
#   'MND2',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YIR025W',
#   'YBL084C',
#   'MND2',
#   'CDC27',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YBL084C',
#   'YDR260C',
#   'CDC27',
#   'SWM1',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YDR260C',
#   'YBL084C',
#   'SWM1',
#   'CDC27',
#   'Affinity',
#   'Capture-MS',
#   'Hall',
#   'MC',
#   'et',
#   'al',
#   '12609981'],
#  ['YMR001C',
#   'YER172C',
#   'CDC5',
#   'BRR2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDR364C',
#   'CDC5',
#   'CDC40',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YMR213W',
#   'CDC5',
#   'CEF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YLR117C',
#   'CDC5',
#   'CLF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YMR240C',
#   'CDC5',
#   'CUS1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YCR063W',
#   'CDC5',
#   'BUD31',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDR163W',
#   'CDC5',
#   'CWC15',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YKL095W',
#   'CDC5',
#   'YJU2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDL209C',
#   'CDC5',
#   'CWC2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDR482C',
#   'CDC5',
#   'CWC21',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YGR278W',
#   'CDC5',
#   'CWC22',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YLR323C',
#   'CDC5',
#   'CWC24',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YPL064C',
#   'CDC5',
#   'CWC27',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YBR065C',
#   'CDC5',
#   'ECM2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YMR288W',
#   'CDC5',
#   'HSH155',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YIR005W',
#   'CDC5',
#   'IST3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YPL213W',
#   'CDC5',
#   'LEA1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YIR009W',
#   'CDC5',
#   'MSL1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YJR050W',
#   'CDC5',
#   'ISY1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDL043C',
#   'CDC5',
#   'PRP11',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YLL036C',
#   'CDC5',
#   'PRP19',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YJL203W',
#   'CDC5',
#   'PRP21',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YER013W',
#   'CDC5',
#   'PRP22',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YAL032C',
#   'CDC5',
#   'PRP45',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YPL151C',
#   'CDC5',
#   'PRP46',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YHR165C',
#   'CDC5',
#   'PRP8',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDL030W',
#   'CDC5',
#   'PRP9',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YML049C',
#   'CDC5',
#   'RSE1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDR088C',
#   'CDC5',
#   'SLU7',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YER029C',
#   'CDC5',
#   'SMB1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YGR074W',
#   'CDC5',
#   'SMD1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YLR275W',
#   'CDC5',
#   'SMD2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YLR147C',
#   'CDC5',
#   'SMD3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YFL017W-A',
#   'CDC5',
#   'SMX2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YPR182W',
#   'CDC5',
#   'SMX3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YKL173W',
#   'CDC5',
#   'SNU114',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YOR148C',
#   'CDC5',
#   'SPP2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YDR416W',
#   'CDC5',
#   'SYF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR001C',
#   'YGR129W',
#   'CDC5',
#   'SYF2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YGL207W',
#   'YML069W',
#   'SPT16',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Lindstrom',
#   'DL',
#   'et',
#   'al',
#   '12556496'],
#  ['YLR418C',
#   'YOL145C',
#   'CDC73',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOL145C',
#   'YLR418C',
#   'CTR9',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YLR418C',
#   'YOL145C',
#   'CDC73',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOL145C',
#   'YLR418C',
#   'CTR9',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YLR418C',
#   'YOR123C',
#   'CDC73',
#   'LEO1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOR123C',
#   'YLR418C',
#   'LEO1',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YLR418C',
#   'YOR123C',
#   'CDC73',
#   'LEO1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOR123C',
#   'YLR418C',
#   'LEO1',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YLR418C',
#   'YBR279W',
#   'CDC73',
#   'PAF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YBR279W',
#   'YLR418C',
#   'PAF1',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YLR418C',
#   'YBR279W',
#   'CDC73',
#   'PAF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YBR279W',
#   'YLR418C',
#   'PAF1',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YLR418C',
#   'YML069W',
#   'CDC73',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YML069W',
#   'YLR418C',
#   'POB3',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YLR418C',
#   'YML069W',
#   'CDC73',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YML069W',
#   'YLR418C',
#   'POB3',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YLR418C',
#   'YGL244W',
#   'CDC73',
#   'RTF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YGL244W',
#   'YLR418C',
#   'RTF1',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YLR418C',
#   'YGL244W',
#   'CDC73',
#   'RTF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YGL244W',
#   'YLR418C',
#   'RTF1',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YLR418C',
#   'YGL207W',
#   'CDC73',
#   'SPT16',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YGL207W',
#   'YLR418C',
#   'SPT16',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YLR418C',
#   'YGL207W',
#   'CDC73',
#   'SPT16',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YGL207W',
#   'YLR418C',
#   'SPT16',
#   'CDC73',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YMR213W',
#   'YER172C',
#   'CEF1',
#   'BRR2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDR364C',
#   'CEF1',
#   'CDC40',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YLR117C',
#   'CEF1',
#   'CLF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YCR063W',
#   'CEF1',
#   'BUD31',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDR163W',
#   'CEF1',
#   'CWC15',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YKL095W',
#   'CEF1',
#   'YJU2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDL209C',
#   'CEF1',
#   'CWC2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YMR213W',
#   'CWC2',
#   'CEF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDR482C',
#   'CEF1',
#   'CWC21',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YGR278W',
#   'CEF1',
#   'CWC22',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YGL128C',
#   'CEF1',
#   'CWC23',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YNL245C',
#   'CEF1',
#   'CWC25',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YGL174W',
#   'CEF1',
#   'BUD13',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YPL064C',
#   'CEF1',
#   'CWC27',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YBR065C',
#   'CEF1',
#   'ECM2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YMR288W',
#   'CEF1',
#   'HSH155',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YIR005W',
#   'CEF1',
#   'IST3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YPL213W',
#   'CEF1',
#   'LEA1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YIR009W',
#   'CEF1',
#   'MSL1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YBR188C',
#   'CEF1',
#   'NTC20',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YJR050W',
#   'CEF1',
#   'ISY1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDL043C',
#   'CEF1',
#   'PRP11',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YLL036C',
#   'CEF1',
#   'PRP19',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YLL036C',
#   'YMR213W',
#   'PRP19',
#   'CEF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YJL203W',
#   'CEF1',
#   'PRP21',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YER013W',
#   'CEF1',
#   'PRP22',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YAL032C',
#   'CEF1',
#   'PRP45',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YPL151C',
#   'CEF1',
#   'PRP46',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YPL151C',
#   'YMR213W',
#   'PRP46',
#   'CEF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YHR165C',
#   'CEF1',
#   'PRP8',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDL030W',
#   'CEF1',
#   'PRP9',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YML049C',
#   'CEF1',
#   'RSE1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDR088C',
#   'CEF1',
#   'SLU7',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YER029C',
#   'CEF1',
#   'SMB1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YGR074W',
#   'CEF1',
#   'SMD1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YLR275W',
#   'CEF1',
#   'SMD2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YLR147C',
#   'CEF1',
#   'SMD3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YFL017W-A',
#   'CEF1',
#   'SMX2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YPR182W',
#   'CEF1',
#   'SMX3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YPR101W',
#   'CEF1',
#   'SNT309',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YPR101W',
#   'YMR213W',
#   'SNT309',
#   'CEF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YKL173W',
#   'CEF1',
#   'SNU114',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YDR416W',
#   'CEF1',
#   'SYF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YMR213W',
#   'YGR129W',
#   'CEF1',
#   'SYF2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YGL130W',
#   'YML010W',
#   'CEG1',
#   'SPT5',
#   'Affinity',
#   'Capture-MS',
#   'Lindstrom',
#   'DL',
#   'et',
#   'al',
#   '12556496'],
#  ['YML010W',
#   'YGL130W',
#   'SPT5',
#   'CEG1',
#   'Affinity',
#   'Capture-MS',
#   'Lindstrom',
#   'DL',
#   'et',
#   'al',
#   '12556496'],
#  ['YMR168C',
#   'YMR094W',
#   'CEP3',
#   'CTF13',
#   'Affinity',
#   'Capture-MS',
#   'Westermann',
#   'S',
#   'et',
#   'al',
#   '14581449'],
#  ['YMR168C',
#   'YDR328C',
#   'CEP3',
#   'SKP1',
#   'Affinity',
#   'Capture-MS',
#   'Westermann',
#   'S',
#   'et',
#   'al',
#   '14581449'],
#  ['YER164W',
#   'YIL035C',
#   'CHD1',
#   'CKA1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YIL035C',
#   'YER164W',
#   'CKA1',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YER164W',
#   'YIL035C',
#   'CHD1',
#   'CKA1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YIL035C',
#   'YER164W',
#   'CKA1',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YER164W',
#   'YOR061W',
#   'CHD1',
#   'CKA2',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOR061W',
#   'YER164W',
#   'CKA2',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YER164W',
#   'YOR061W',
#   'CHD1',
#   'CKA2',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOR061W',
#   'YER164W',
#   'CKA2',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YER164W',
#   'YGL019W',
#   'CHD1',
#   'CKB1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YER164W',
#   'YGL019W',
#   'CHD1',
#   'CKB1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YER164W',
#   'YOR039W',
#   'CHD1',
#   'CKB2',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YER164W',
#   'YOR039W',
#   'CHD1',
#   'CKB2',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YER164W',
#   'YML069W',
#   'CHD1',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YML069W',
#   'YER164W',
#   'POB3',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YER164W',
#   'YML069W',
#   'CHD1',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YML069W',
#   'YER164W',
#   'POB3',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YER164W',
#   'YGL207W',
#   'CHD1',
#   'SPT16',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YGL207W',
#   'YER164W',
#   'SPT16',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YER164W',
#   'YGL207W',
#   'CHD1',
#   'SPT16',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YGL207W',
#   'YER164W',
#   'SPT16',
#   'CHD1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YPR119W',
#   'YBR160W',
#   'CLB2',
#   'CDC28',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YBR135W',
#   'CLB2',
#   'CKS1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YGR108W',
#   'CLB2',
#   'CLB1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YPL119C',
#   'CLB2',
#   'DBP1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YOR204W',
#   'CLB2',
#   'DED1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YPL031C',
#   'CLB2',
#   'PHO85',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YDL055C',
#   'CLB2',
#   'PSA1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YLR079W',
#   'CLB2',
#   'SIC1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YAL005C',
#   'CLB2',
#   'SSA1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YLL024C',
#   'CLB2',
#   'SSA2',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YBL075C',
#   'CLB2',
#   'SSA3',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YER103W',
#   'CLB2',
#   'SSA4',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YNL209W',
#   'CLB2',
#   'SSB2',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YDR172W',
#   'CLB2',
#   'SUP35',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YPR080W',
#   'CLB2',
#   'TEF1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YBR118W',
#   'CLB2',
#   'TEF2',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YER151C',
#   'CLB2',
#   'UBP3',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YCR030C',
#   'CLB2',
#   'SYP1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YDL229W',
#   'CLB2',
#   'SSB1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YIL105C',
#   'CLB2',
#   'SLM1',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YPR119W',
#   'YLL054C',
#   'CLB2',
#   'YLL054C',
#   'Affinity',
#   'Capture-MS',
#   'Honey',
#   'S',
#   'et',
#   'al',
#   '11160944'],
#  ['YOL145C',
#   'YOR123C',
#   'CTR9',
#   'LEO1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOR123C',
#   'YOL145C',
#   'LEO1',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOL145C',
#   'YOR123C',
#   'CTR9',
#   'LEO1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOR123C',
#   'YOL145C',
#   'LEO1',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOL145C',
#   'YBR279W',
#   'CTR9',
#   'PAF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YBR279W',
#   'YOL145C',
#   'PAF1',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOL145C',
#   'YBR279W',
#   'CTR9',
#   'PAF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YBR279W',
#   'YOL145C',
#   'PAF1',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOL145C',
#   'YML069W',
#   'CTR9',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YML069W',
#   'YOL145C',
#   'POB3',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOL145C',
#   'YML069W',
#   'CTR9',
#   'POB3',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YML069W',
#   'YOL145C',
#   'POB3',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOL145C',
#   'YGL244W',
#   'CTR9',
#   'RTF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YGL244W',
#   'YOL145C',
#   'RTF1',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOL145C',
#   'YGL244W',
#   'CTR9',
#   'RTF1',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YGL244W',
#   'YOL145C',
#   'RTF1',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOL145C',
#   'YGL207W',
#   'CTR9',
#   'SPT16',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YGL207W',
#   'YOL145C',
#   'SPT16',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '12242279'],
#  ['YOL145C',
#   'YGL207W',
#   'CTR9',
#   'SPT16',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YGL207W',
#   'YOL145C',
#   'SPT16',
#   'CTR9',
#   'Affinity',
#   'Capture-MS',
#   'Krogan',
#   'NJ',
#   'et',
#   'al',
#   '14759368'],
#  ['YOL145C',
#   'YOR123C',
#   'CTR9',
#   'LEO1',
#   'Affinity',
#   'Capture-MS',
#   'Squazzo',
#   'SL',
#   'et',
#   'al',
#   '11927560'],
#  ['YOL145C',
#   'YGL244W',
#   'CTR9',
#   'RTF1',
#   'Affinity',
#   'Capture-MS',
#   'Squazzo',
#   'SL',
#   'et',
#   'al',
#   '11927560'],
#  ['YOL145C',
#   'YML010W',
#   'CTR9',
#   'SPT5',
#   'Affinity',
#   'Capture-MS',
#   'Squazzo',
#   'SL',
#   'et',
#   'al',
#   '11927560'],
#  ['YDL209C',
#   'YDR364C',
#   'CWC2',
#   'CDC40',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YMR213W',
#   'CWC2',
#   'CEF1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YLR117C',
#   'CWC2',
#   'CLF1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YGR278W',
#   'CWC2',
#   'CWC22',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YGL128C',
#   'CWC2',
#   'CWC23',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YBR065C',
#   'CWC2',
#   'ECM2',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YJR050W',
#   'CWC2',
#   'ISY1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YPL213W',
#   'CWC2',
#   'LEA1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YLL036C',
#   'CWC2',
#   'PRP19',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YGL120C',
#   'CWC2',
#   'PRP43',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YAL032C',
#   'CWC2',
#   'PRP45',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YPL151C',
#   'CWC2',
#   'PRP46',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YHR165C',
#   'CWC2',
#   'PRP8',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YER029C',
#   'CWC2',
#   'SMB1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YGR074W',
#   'CWC2',
#   'SMD1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YLR147C',
#   'CWC2',
#   'SMD3',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YPR101W',
#   'CWC2',
#   'SNT309',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YKL173W',
#   'CWC2',
#   'SNU114',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YDR416W',
#   'CWC2',
#   'SYF1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YGR129W',
#   'CWC2',
#   'SYF2',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YKL095W',
#   'CWC2',
#   'YJU2',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YKR022C',
#   'CWC2',
#   'YKR022C',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YLR424W',
#   'CWC2',
#   'SPP382',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YLR424W',
#   'YDL209C',
#   'SPP382',
#   'CWC2',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDL209C',
#   'YER172C',
#   'CWC2',
#   'BRR2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YDR364C',
#   'CWC2',
#   'CDC40',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YLR117C',
#   'CWC2',
#   'CLF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YCR063W',
#   'CWC2',
#   'BUD31',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YDR163W',
#   'CWC2',
#   'CWC15',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YKL095W',
#   'CWC2',
#   'YJU2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YDR482C',
#   'CWC2',
#   'CWC21',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YLR323C',
#   'CWC2',
#   'CWC24',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YNL245C',
#   'CWC2',
#   'CWC25',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YGL174W',
#   'CWC2',
#   'BUD13',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YBR065C',
#   'CWC2',
#   'ECM2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YBR086C',
#   'CWC2',
#   'IST2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YPL213W',
#   'CWC2',
#   'LEA1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YIR009W',
#   'CWC2',
#   'MSL1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YBR188C',
#   'CWC2',
#   'NTC20',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YJR050W',
#   'CWC2',
#   'ISY1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YLL036C',
#   'CWC2',
#   'PRP19',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YLL036C',
#   'YDL209C',
#   'PRP19',
#   'CWC2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YAL032C',
#   'CWC2',
#   'PRP45',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YPL151C',
#   'CWC2',
#   'PRP46',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YPL151C',
#   'YDL209C',
#   'PRP46',
#   'CWC2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YHR165C',
#   'CWC2',
#   'PRP8',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YDR088C',
#   'CWC2',
#   'SLU7',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YER029C',
#   'CWC2',
#   'SMB1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YGR074W',
#   'CWC2',
#   'SMD1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YLR275W',
#   'CWC2',
#   'SMD2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YLR147C',
#   'CWC2',
#   'SMD3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YPR182W',
#   'CWC2',
#   'SMX3',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YPR101W',
#   'CWC2',
#   'SNT309',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YPR101W',
#   'YDL209C',
#   'SNT309',
#   'CWC2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YKL173W',
#   'CWC2',
#   'SNU114',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YOR148C',
#   'CWC2',
#   'SPP2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YDR416W',
#   'CWC2',
#   'SYF1',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YDL209C',
#   'YGR129W',
#   'CWC2',
#   'SYF2',
#   'Affinity',
#   'Capture-MS',
#   'Ohi',
#   'MD',
#   'et',
#   'al',
#   '11884590'],
#  ['YNL245C',
#   'YLR117C',
#   'CWC25',
#   'CLF1',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YNL245C',
#   'YLL036C',
#   'CWC25',
#   'PRP19',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YNL245C',
#   'YHR165C',
#   'CWC25',
#   'PRP8',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YNL245C',
#   'YKL173W',
#   'CWC25',
#   'SNU114',
#   'Affinity',
#   'Capture-MS',
#   'Hazbun',
#   'TR',
#   'et',
#   'al',
#   '14690591'],
#  ['YDR016C',
#   'YKL052C',
#   'DAD1',
#   'ASK1',
#   'Affinity',
#   'Capture-MS',
#   'Cheeseman',
#   'IM',
#   'et',
#   'al',
#   '12408861'],
#  ['YDR016C',
#   'YKR083C',
#   'DAD1',
#   'DAD2',
#   'Affinity',
#   'Capture-MS',
#   'Cheeseman',
#   'IM',
#   'et',
#   'al',
#   '12408861'],
#  ['YDR016C',
#   'YBR233W-A',
#   'DAD1',
#   'DAD3',
#   'Affinity',
#   'Capture-MS',
#   'Cheeseman',
#   'IM',
#   'et',
#   'al',
#   '12408861'],
#  ['YDR016C',
#   'YDR320C-A',
#   'DAD1',
#   'DAD4',
#   'Affinity',
#   'Capture-MS',
#   'Cheeseman',
#   'IM',
#   'et',
#   'al',
# ...
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YPR144C',
#   'NOP14',
#   'NOC4',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YCR057C',
#   'NOC4',
#   'PWP2',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YCR057C',
#   'YPR144C',
#   'PWP2',
#   'NOC4',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YBR031W',
#   'NOC4',
#   'RPL4A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YDR064W',
#   'NOC4',
#   'RPS13',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YML024W',
#   'NOC4',
#   'RPS17A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YDR447C',
#   'NOC4',
#   'RPS17B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YJR145C',
#   'NOC4',
#   'RPS4A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YHR203C',
#   'NOC4',
#   'RPS4B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YOR096W',
#   'NOC4',
#   'RPS7A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YBL072C',
#   'NOC4',
#   'RPS8A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YER102W',
#   'NOC4',
#   'RPS8B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YPL081W',
#   'NOC4',
#   'RPS9A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YPL012W',
#   'NOC4',
#   'RRP12',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YMR229C',
#   'NOC4',
#   'RRP5',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YLL011W',
#   'NOC4',
#   'SOF1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YBL004W',
#   'NOC4',
#   'UTP20',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YDR324C',
#   'NOC4',
#   'UTP4',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YDR449C',
#   'NOC4',
#   'UTP6',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDR449C',
#   'YPR144C',
#   'UTP6',
#   'NOC4',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YGR090W',
#   'NOC4',
#   'UTP22',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YGR090W',
#   'YPR144C',
#   'UTP22',
#   'NOC4',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YGR128C',
#   'NOC4',
#   'UTP8',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YGR145W',
#   'NOC4',
#   'ENP2',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YJL109C',
#   'NOC4',
#   'UTP10',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YLR222C',
#   'NOC4',
#   'UTP13',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPR144C',
#   'YMR093W',
#   'NOC4',
#   'UTP15',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPL093W',
#   'YDR101C',
#   'NOG1',
#   'ARX1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YOL077C',
#   'NOG1',
#   'BRX1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YHR052W',
#   'NOG1',
#   'CIC1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YNL112W',
#   'NOG1',
#   'DBP2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YKR024C',
#   'NOG1',
#   'DBP7',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YPR175W',
#   'NOG1',
#   'DPB2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YMR049C',
#   'NOG1',
#   'ERB1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YML074C',
#   'NOG1',
#   'FPR3',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YLR449W',
#   'NOG1',
#   'FPR4',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YMR290C',
#   'NOG1',
#   'HAS1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YBR142W',
#   'NOG1',
#   'MAK5',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YKL009W',
#   'NOG1',
#   'MRT4',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YOR206W',
#   'NOG1',
#   'NOC2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YPL093W',
#   'NOG1',
#   'NOG1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YNR053C',
#   'NOG1',
#   'NOG2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YNR053C',
#   'YPL093W',
#   'NOG2',
#   'NOG1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YNR053C',
#   'NOG1',
#   'NOG2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '11707418'],
#  ['YNR053C',
#   'YPL093W',
#   'NOG2',
#   'NOG1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '11707418'],
#  ['YPL093W',
#   'YDL014W',
#   'NOG1',
#   'NOP1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YOL041C',
#   'NOG1',
#   'NOP12',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YER002W',
#   'NOG1',
#   'NOP16',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YNL061W',
#   'NOG1',
#   'NOP2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YOR310C',
#   'NOG1',
#   'NOP58',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YGR103W',
#   'NOG1',
#   'NOP7',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YGL111W',
#   'NOG1',
#   'NSA1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YER126C',
#   'NOG1',
#   'NSA2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YER006W',
#   'NOG1',
#   'NUG1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YDR496C',
#   'NOG1',
#   'PUF6',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YHR197W',
#   'NOG1',
#   'RIX1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YLR009W',
#   'NOG1',
#   'RLP24',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YLR009W',
#   'YPL093W',
#   'RLP24',
#   'NOG1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YLR009W',
#   'NOG1',
#   'RLP24',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '11707418'],
#  ['YLR009W',
#   'YPL093W',
#   'RLP24',
#   'NOG1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '11707418'],
#  ['YPL093W',
#   'YNL002C',
#   'NOG1',
#   'RLP7',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YHR088W',
#   'NOG1',
#   'RPF1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YKR081C',
#   'NOG1',
#   'RPF2',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YDR087C',
#   'NOG1',
#   'RRP1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YGR245C',
#   'NOG1',
#   'SDA1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YFL002C',
#   'NOG1',
#   'SPB4',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YPR016C',
#   'NOG1',
#   'TIF6',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YCR072C',
#   'NOG1',
#   'YCR072C',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YOR252W',
#   'NOG1',
#   'RBF17',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YPL146C',
#   'NOG1',
#   'RRP16',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YPL093W',
#   'YOR272W',
#   'NOG1',
#   'YTM1',
#   'Affinity',
#   'Capture-MS',
#   'Saveanu',
#   'C',
#   'et',
#   'al',
#   '12808088'],
#  ['YDL014W',
#   'YJR002W',
#   'NOP1',
#   'MPP10',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YDL148C',
#   'YDR299W',
#   'NOP14',
#   'BFR2',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YPL217C',
#   'NOP14',
#   'BMS1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YMR128W',
#   'NOP14',
#   'ECM16',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YLR186W',
#   'NOP14',
#   'EMG1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YMR290C',
#   'NOP14',
#   'HAS1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YNL132W',
#   'NOP14',
#   'KRE33',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YGR100W',
#   'NOP14',
#   'MDR1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YJR002W',
#   'NOP14',
#   'MPP10',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YPL126W',
#   'NOP14',
#   'NAN1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YDL014W',
#   'NOP14',
#   'NOP1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YDL148C',
#   'NOP14',
#   'NOP14',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YBR031W',
#   'NOP14',
#   'RPL4A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YBR048W',
#   'NOP14',
#   'RPS11B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YML024W',
#   'NOP14',
#   'RPS17A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YDR447C',
#   'NOP14',
#   'RPS17B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YLR441C',
#   'NOP14',
#   'RPS1A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YIL069C',
#   'NOP14',
#   'RPS24B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YJR145C',
#   'NOP14',
#   'RPS4A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YHR203C',
#   'NOP14',
#   'RPS4B',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YOR096W',
#   'NOP14',
#   'RPS7A',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YPL012W',
#   'NOP14',
#   'RRP12',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YMR229C',
#   'NOP14',
#   'RRP5',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YBL004W',
#   'NOP14',
#   'UTP20',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YGR090W',
#   'NOP14',
#   'UTP22',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YGR090W',
#   'YDL148C',
#   'UTP22',
#   'NOP14',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YGR128C',
#   'NOP14',
#   'UTP8',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YGR128C',
#   'YDL148C',
#   'UTP8',
#   'NOP14',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YLR222C',
#   'NOP14',
#   'UTP13',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YDL148C',
#   'YJR002W',
#   'NOP14',
#   'MPP10',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YPL043W',
#   'YMR290C',
#   'NOP4',
#   'HAS1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPL043W',
#   'YNL132W',
#   'NOP4',
#   'KRE33',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPL043W',
#   'YLR197W',
#   'NOP4',
#   'SIK1',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPL043W',
#   'YPL012W',
#   'NOP4',
#   'RRP12',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPL043W',
#   'YMR229C',
#   'NOP4',
#   'RRP5',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YPL043W',
#   'YBL004W',
#   'NOP4',
#   'UTP20',
#   'Affinity',
#   'Capture-MS',
#   'Grandi',
#   'P',
#   'et',
#   'al',
#   '12150911'],
#  ['YOR310C',
#   'YOR078W',
#   'NOP58',
#   'BUD21',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YMR128W',
#   'NOP58',
#   'ECM16',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YLR129W',
#   'NOP58',
#   'DIP2',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YHR148W',
#   'NOP58',
#   'IMP3',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YNL075W',
#   'NOP58',
#   'IMP4',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YJR002W',
#   'NOP58',
#   'MPP10',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YPL126W',
#   'NOP58',
#   'NAN1',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YDL014W',
#   'NOP58',
#   'NOP1',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YDL148C',
#   'NOP58',
#   'NOP14',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YLR197W',
#   'NOP58',
#   'SIK1',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YCR057C',
#   'NOP58',
#   'PWP2',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YMR229C',
#   'NOP58',
#   'RRP5',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YPR137W',
#   'NOP58',
#   'RRP9',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YDL153C',
#   'NOP58',
#   'SAS10',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YEL026W',
#   'NOP58',
#   'SNU13',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YLL011W',
#   'NOP58',
#   'SOF1',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YJL109C',
#   'NOP58',
#   'UTP10',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ['YOR310C',
#   'YKL099C',
#   'NOP58',
#   'UTP11',
#   'Affinity',
#   'Capture-MS',
#   'Dragon',
#   'F',
#   'et',
#   'al',
#   '12068309'],
#  ...]

# %%
archivoAbierto = list()


for array in LITREG
    archivoAbierto[i] = {LITREG[i][0], LITREG[i][1]}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9dfdb5624879> in <module>()
#       2
#       3
# ----> 4 while LITREG[i][0] != '':
#       5     archivoAbierto[i] = {LITREG[i][0], LITREG[i][1]}
#       6
#
# NameError: name 'i' is not defined

# %%
LITREG[1][0]
# Out:
# 'YBR236C'
